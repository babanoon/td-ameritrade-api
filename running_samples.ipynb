# %%
#pip install -e .

# %%
from configparser import ConfigParser
from td.credentials import TdCredentials
from td.client import TdAmeritradeClient

import inspect

import pandas as pd
from pprint import pprint

# %%
# Permanent parameters:

config_file='config/config.ini'
credential_file='config/td_credentials.json'

# %% [markdown]
# # Section 1: Authorization

# %%
# Initialize the Parser.
config = ConfigParser()

# %%
# Read the file.
config.read(config_file)
# Out:
# ['config/config.ini']

# %%
# Get the specified credentials.
client_id = config.get('main', 'client_id')
redirect_uri = config.get('main', 'redirect_uri')

# %%
redirect_uri
# Out:
# 'http://127.0.0.1'

# %%
# Intialize our `Crednetials` object.
td_credentials = TdCredentials(
    
    client_id=client_id,

    redirect_uri=redirect_uri,

    credential_file=credential_file    # just in case the file exists, it won't do authorizatio again. 
)

# %%
# Saving the credential JSON file:
td_credentials.to_credential_file(
    file_path=credential_file
)

# %%
# Initalize the `TdAmeritradeClient`
td_client = TdAmeritradeClient(
    credentials=td_credentials
)

# %% [markdown]
# # use_quotes

# %%
# Initialize the `Quotes` service.
quote_service = td_client.quotes()

# %%
# Grab a single quote.
print(
    quote_service.get_quote(instrument='AAPL')
)
# Out:
# {'AAPL': {'assetType': 'EQUITY', 'assetMainType': 'EQUITY', 'cusip': '037833100', 'assetSubType': '', 'symbol': 'AAPL', 'description': 'Apple Inc. - Common Stock', 'bidPrice': 143.8, 'bidSize': 6100, 'bidId': 'P', 'askPrice': 143.85, 'askSize': 300, 'askId': 'P', 'lastPrice': 143.8, 'lastSize': 0, 'lastId': 'D', 'openPrice': 142.7, 'highPrice': 144.34, 'lowPrice': 142.28, 'bidTick': ' ', 'closePrice': 143.0, 'netChange': 0.8, 'totalVolume': 65874459, 'quoteTimeInLong': 1675213183986, 'tradeTimeInLong': 1675213198390, 'mark': 143.85, 'exchange': 'q', 'exchangeName': 'NASD', 'marginable': True, 'shortable': True, 'volatility': 0.0132, 'digits': 4, '52WkHigh': 179.61, '52WkLow': 124.17, 'nAV': 0.0, 'peRatio': 23.9147, 'divAmount': 0.92, 'divYield': 0.64, 'divDate': '2022-11-04 00:00:00.000', 'securityStatus': 'Normal', 'regularMarketLastPrice': 144.29, 'regularMarketLastSize': 146208, 'regularMarketNetChange': 1.29, 'regularMarketTradeTimeInLong': 1675198801523, 'netPercentChangeInDouble': 0.5594, 'markChangeInDouble': 0.85, 'markPercentChangeInDouble': 0.5944, 'regularMarketPercentChangeInDouble': 0.9021, 'delayed': False, 'realtimeEntitled': True}}

# %% [markdown]
# ### Success!

# %% [markdown]
# ## Price History

# %%
from td.utils.enums import PeriodType
from td.utils.enums import FrequencyType


from datetime import datetime
from datetime import timedelta

# %%
# Initialize the `PriceHistory` service.
price_history_service = td_client.price_history()

# %%
# Grab the Price History, with enums.
price_history = price_history_service.get_price_history(
    symbol='MSFT',
    frequency_type=FrequencyType.Minute,
    frequency=1,
    period_type=PeriodType.Day,
    period=10,
    extended_hours_needed=False
)

# %%
# The max look back period for minute data is 31 Days.
end_date = datetime.now()
start_date = datetime.now() - timedelta(days=60)

# %%
# Grab the Price History, custom time frame.
price_history = price_history_service.get_price_history(
    symbol='MSFT',
    frequency_type=FrequencyType.Minute,
    frequency=1,
    start_date=start_date,
    end_date=end_date,
    extended_hours_needed=False
)

# %%
#price_history

# %%
# print(price_history['candles'])

# %% [markdown]
# # use movers

# %%
# Initialize the `Movers` service.
movers_service = td_client.movers()

# Grab the top 10 percentage up movers.
pprint(
    movers_service.get_movers(
        index='$DJI',
        direction='down',
        change='percent'
    )
)
# Out:
# [{'change': -0.03521988527724668,
#   'description': 'Caterpillar, Inc. Common Stock',
#   'direction': 'down',
#   'last': 252.29,
#   'symbol': 'CAT',
#   'totalVolume': 15929517},
#  {'change': -0.012883458230278007,
#   'description': "McDonald's Corporation Common Stock",
#   'direction': 'down',
#   'last': 267.4,
#   'symbol': 'MCD',
#   'totalVolume': 8102062},
#  {'change': -0.004212860310421445,
#   'description': 'International Business Machines Corporation Common Stock',
#   'direction': 'down',
#   'last': 134.73,
#   'symbol': 'IBM',
#   'totalVolume': 13729472},
#  {'change': -0.0010332950631456856,
#   'description': 'Chevron Corporation Common Stock',
#   'direction': 'down',
#   'last': 174.02,
#   'symbol': 'CVX',
#   'totalVolume': 27322174}]

# %% [markdown]
# # Use orders

# %%
from td.utils.enums import OrderStatus

# %%
# This piece of info from the config file was not necessary until this time:
account_number = config.get('main', 'account_number')

# %%
# Initialize the `Orders` service.
orders_service = td_client.orders()

# Query all our orders for a specific account.
pprint(
    orders_service.get_orders_by_path(
        account_id=account_number,
        order_status=OrderStatus.Expired
        #order_status=OrderStatus.Queded
    )
)
# Out:
# []

# %%
# Query all our orders.
pprint(
    orders_service.get_orders_by_query()
)
# Out:
# []

# %% [markdown]
# BIG HINT: We can set the BEGIN and END values for the order history, see the code.

# %% [markdown]
# # option chain

# %%
from td.utils.enums import OptionaRange
from td.utils.enums import OptionType
from td.utils.enums import ContractType
from td.utils.enums import ExpirationMonth
from td.utils.option_chain import OptionChainQuery

# %%
# Initialize the `OptionsChain` service.
options_chain_service = td_client.options_chain()

# %%
# Method 1: Build a Query using the `OptionChainQuery` object.
# This method is preferred because I'll check some of your inputs
# to make sure you are sending the correct parameters.
option_chain_query = OptionChainQuery(
    symbol='MSFT',
    contract_type=ContractType.Call,
    expiration_month=ExpirationMonth.June,
    option_type=OptionType.StandardContracts,
    option_range=OptionaRange.InTheMoney,
    include_quotes=True
)

# %%
# Query the Options Data.

# Big hint: it seems that it cannot be run twice!
options_data = options_chain_service.get_option_chain(
    option_chain_query=option_chain_query
)

pprint(options_data['numberOfContracts'])
# Out:
# 930

# %% [markdown]
# The original repo suggests a second methos, which is exactly the same as this one, but instead of using utils, the dictionary is made manually. I'm not bringing that.

# %% [markdown]
# # Use streaming client

# %%
from td.utils.enums import LevelOneQuotes
from td.utils.enums import LevelOneOptions
from td.utils.enums import LevelOneFutures
from td.utils.enums import LevelOneForex
from td.utils.enums import LevelOneFuturesOptions
from td.utils.enums import NewsHeadlines
from td.utils.enums import ChartServices
from td.utils.enums import ChartEquity
from td.utils.enums import TimesaleServices
from td.utils.enums import Timesale
from td.utils.enums import ActivesServices
from td.utils.enums import ActivesVenues
from td.utils.enums import ActivesDurations
from td.utils.enums import ChartFuturesFrequencies
from td.utils.enums import ChartFuturesPeriods
from td.utils.enums import LevelTwoQuotes
from td.utils.enums import LevelTwoOptions

# %%
# Initialize the `StreamingApiClient` service.
streaming_api_service = td_client.streaming_api_client()

# %%
# Let's see what services we have access to.
streaming_services = streaming_api_service.services()

# %%
# Set the Quality of Service.
streaming_services.quality_of_service(
    qos_level='1'
)

# %%
# Grab level one quotes.
streaming_services.level_one_quotes(
    symbols=['MSFT'],
    fields=LevelOneQuotes.All
)

# %%
# Grab level one options quotes.
streaming_services.level_one_options(
    symbols=['MSFT_043021C120'],
    fields=LevelOneOptions.All
)

# %%
# Grab level one futures quotes.
streaming_services.level_one_futures(
    symbols=['/ESM4', '/ES'],
    fields=LevelOneFutures.All
)

# %%
# Grab level one forex quotes.
streaming_services.level_one_forex(
    symbols=['EUR/USD'],
    fields=LevelOneForex.All
)

# %%
# Stream News Headlines.
streaming_services.news_headline(
    symbols=['MSFT', 'GOOG', 'AAPL'],
    fields=NewsHeadlines.All
)

# %%
# Stream Level One Futures Options.
streaming_services.level_one_futures_options(
    symbols=['./CLM21P625'],
    fields=LevelOneFuturesOptions.All
)

# %%
# Stream equity bars.
streaming_services.chart(
    service=ChartServices.ChartEquity,
    symbols=['MSFT', 'GOOG', 'AAPL'],
    fields=ChartEquity.All
)

# %%
# Stream Time & Sales data.
streaming_services.timesale(
    service=TimesaleServices.TimesaleEquity,
    symbols=['MSFT', 'GOOG', 'AAPL'],
    fields=Timesale.All
)

# %%
# Stream the Actives.
streaming_services.actives(
    service=ActivesServices.ActivesNasdaq,
    venue=ActivesVenues.NasdaqExchange,
    duration=ActivesDurations.All
)

# %%
# Stream Historical Futures Prices.
streaming_services.chart_history_futures(
    symbols=['/ES', '/CL'],
    frequency=ChartFuturesFrequencies.OneMinute,
    period=ChartFuturesPeriods.OneDay
)

# %%
# Stream Level Two Quotes.
streaming_services.level_two_quotes(
    symbols=['MSFT', 'PINS'],
    fields=LevelTwoQuotes.All
)

# %%
# Stream Level Two Quotes.
streaming_services.level_two_options(
    symbols=['MSFT_043021C120'],
    fields=LevelTwoOptions.All
)

# %%
# Start Streaming.

# Hint: this does not work in a notebook!

#streaming_api_service.open_stream()

# %% [markdown]
# Can't run it in a notebook. I tested the code: "./samples/temp_use_streaming_client.py" which I modified by changing the '../config/config.ini'

# %% [markdown]
# # Data pipeline

# %%
async def data_pipeline():
    """
    This is an example of how to build a data pipeline,
    using the library. A common scenario that would warrant
    using a pipeline is taking data that is sent back to the stream
    and processing it so it can be used in other programs or functions.

    Generally speaking, you will need to wrap the operations that process
    and handle the data inside an async function. The reason being is so
    that you can await the return of data.

    However, operations like creating the client, and subscribing to services
    can be performed outside the async function. In the example below, we demonstrate
    building the pipline, which is connecting to the websocket and logging in.

    We then start the pipeline, which is where the services are subscribed to and data
    begins streaming. The `start_pipeline()` will return the data as it comes in. From
    there, we process the data however we choose.

    Additionally, we can also see how to unsubscribe from a stream using logic and how
    to close the socket mid-stream.
    """

    data_response_count = 0
    heartbeat_response_count = 0

    # Build the Pipeline.
    await streaming_api_service.build_pipeline()

    # Keep going as long as we can recieve data.
    while True:

        # Start the Pipeline.
        data = await streaming_api_service.start_pipeline()

        # Grab the Data, if there was any. Remember not every message will have `data.`
        if data and 'data' in data:

            print('='*80)

            data_content = data['data'][0]['content']
            pprint(data_content, indent=4)

            # Here I can grab data as it comes in and do something with it.
            if 'key' in data_content[0]:
                print('Here is my key: {}'.format(data_content[0]['key']))

            print('-'*80)
            data_response_count += 1

        # If we get a heartbeat notice, let's increment our counter.
        elif data and 'notify' in data:
            print(data['notify'][0])
            heartbeat_response_count += 1

        # Once we have 1 data responses, we can unsubscribe from a service.
        if data_response_count == 1:
            unsub = await streaming_api_service.unsubscribe(service='LEVELONE_QUOTES')
            data_response_count += 1
            print('='*80)
            print(unsub)
            print('-'*80)

        # Once we have 5 heartbeats, let's close the stream. Make sure to break the while loop.
        # or else you will encounter an exception.
        if heartbeat_response_count == 3:
            await streaming_api_service.close_stream()
            break

        heartbeat_response_count += 1

# %%
#data_pipeline()

# %% [markdown]
# # use accounts

# %%
# Initialize the `Accounts` service.
accounts_service = td_client.accounts()

# %%
# Grab all the Positions and Orders for a specific account.
pprint(
    accounts_service.get_accounts(
        account_id=account_number,
        include_orders=True,
        include_positions=True
    )
)
# Out:
# Access Token Expired, refreshing access token...
# {'securitiesAccount': {'accountId': '253157675',
#                        'currentBalances': {'accruedInterest': 0.0,
#                                            'availableFunds': 2175.74,
#                                            'availableFundsNonMarginableTrade': 2175.74,
#                                            'bondValue': 0.0,
#                                            'buyingPower': 4351.48,
#                                            'buyingPowerNonMarginableTrade': 2175.74,
#                                            'cashBalance': 1250.21,
#                                            'cashReceipts': 0.0,
#                                            'dayTradingBuyingPower': 0.0,
#                                            'equity': 2973.16,
#                                            'equityPercentage': 100.0,
#                                            'liquidationValue': 2973.16,
#                                            'longMarginValue': 1722.95,
#                                            'longMarketValue': 1722.95,
#                                            'longOptionMarketValue': 0.0,
#                                            'maintenanceCall': 0.0,
#                                            'maintenanceRequirement': 518.43,
#                                            'marginBalance': 0.0,
#                                            'moneyMarketFund': 0.0,
#                                            'mutualFundValue': 0.0,
#                                            'pendingDeposits': 0.0,
#                                            'regTCall': 0.0,
#                                            'savings': 0.0,
#                                            'shortBalance': 0.0,
#                                            'shortMarginValue': 0.0,
#                                            'shortMarketValue': 0.0,
#                                            'shortOptionMarketValue': 0.0,
#                                            'sma': 2175.74},
#                        'initialBalances': {'accountValue': 2954.9,
#                                            'accruedInterest': 0.0,
#                                            'availableFundsNonMarginableTrade': 2175.74,
#                                            'bondValue': 0.0,
#                                            'buyingPower': 4351.48,
#                                            'cashAvailableForTrading': 0.0,
#                                            'cashBalance': 1250.21,
#                                            'cashReceipts': 0.0,
#                                            'dayTradingBuyingPower': 0.0,
#                                            'dayTradingBuyingPowerCall': 0.0,
#                                            'dayTradingEquityCall': 0.0,
#                                            'equity': 2954.9,
#                                            'equityPercentage': 100.0,
#                                            'isInCall': False,
#                                            'liquidationValue': 2954.9,
#                                            'longMarginValue': 1704.69,
#                                            'longOptionMarketValue': 0.0,
#                                            'longStockValue': 1704.69,
#                                            'maintenanceCall': 0.0,
#                                            'maintenanceRequirement': 512.94,
#                                            'margin': 1250.21,
#                                            'marginBalance': 0.0,
#                                            'marginEquity': 2954.9,
#                                            'moneyMarketFund': 0.0,
#                                            'mutualFundValue': 0.0,
#                                            'pendingDeposits': 0.0,
#                                            'regTCall': 0.0,
#                                            'shortBalance': 0.0,
#                                            'shortMarginValue': 0.0,
#                                            'shortOptionMarketValue': 0.0,
#                                            'shortStockValue': 0.0,
#                                            'totalCash': 0.0},
#                        'isClosingOnlyRestricted': False,
#                        'isDayTrader': False,
#                        'positions': [{'averagePrice': 369.71,
#                                       'currentDayCost': 0.0,
#                                       'currentDayProfitLoss': 18.25,
#                                       'currentDayProfitLossPercentage': 1.07,
#                                       'instrument': {'assetType': 'EQUITY',
#                                                      'cusip': '532457108',
#                                                      'symbol': 'LLY'},
#                                       'longQuantity': 5.0,
#                                       'maintenanceRequirement': 516.23,
#                                       'marketValue': 1720.75,
#                                       'previousSessionLongQuantity': 5.0,
#                                       'settledLongQuantity': 5.0,
#                                       'settledShortQuantity': 0.0,
#                                       'shortQuantity': 0.0},
#                                      {'averagePrice': 2.29,
#                                       'currentDayCost': 0.0,
#                                       'currentDayProfitLoss': 0.01,
#                                       'currentDayProfitLossPercentage': 0.46,
#                                       'instrument': {'assetType': 'EQUITY',
#                                                      'cusip': '00211Y506',
#                                                      'symbol': 'ABIO'},
#                                       'longQuantity': 1.0,
#                                       'maintenanceRequirement': 2.2,
#                                       'marketValue': 2.2,
#                                       'previousSessionLongQuantity': 1.0,
#                                       'settledLongQuantity': 1.0,
#                                       'settledShortQuantity': 0.0,
#                                       'shortQuantity': 0.0}],
#                        'projectedBalances': {'availableFunds': 2175.74,
#                                              'availableFundsNonMarginableTrade': 2175.74,
#                                              'buyingPower': 4351.48,
#                                              'dayTradingBuyingPower': 0.0,
#                                              'dayTradingBuyingPowerCall': 0.0,
#                                              'isInCall': False,
#                                              'maintenanceCall': 0.0,
#                                              'regTCall': 0.0,
#                                              'stockBuyingPower': 4351.48},
#                        'roundTrips': 0,
#                        'type': 'MARGIN'}}

# %%
from td.utils.enums import TransactionTypes
# Grab all the Positions and Orders for all my accounts.
pprint(
    accounts_service.get_accounts(
        include_orders=True,
        include_positions=True
    )
)
# Out:
# [{'securitiesAccount': {'accountId': '253157675',
#                         'currentBalances': {'accruedInterest': 0.0,
#                                             'availableFunds': 2175.74,
#                                             'availableFundsNonMarginableTrade': 2175.74,
#                                             'bondValue': 0.0,
#                                             'buyingPower': 4351.48,
#                                             'buyingPowerNonMarginableTrade': 2175.74,
#                                             'cashBalance': 1250.21,
#                                             'cashReceipts': 0.0,
#                                             'dayTradingBuyingPower': 0.0,
#                                             'equity': 2973.16,
#                                             'equityPercentage': 100.0,
#                                             'liquidationValue': 2973.16,
#                                             'longMarginValue': 1722.95,
#                                             'longMarketValue': 1722.95,
#                                             'longOptionMarketValue': 0.0,
#                                             'maintenanceCall': 0.0,
#                                             'maintenanceRequirement': 518.43,
#                                             'marginBalance': 0.0,
#                                             'moneyMarketFund': 0.0,
#                                             'mutualFundValue': 0.0,
#                                             'pendingDeposits': 0.0,
#                                             'regTCall': 0.0,
#                                             'savings': 0.0,
#                                             'shortBalance': 0.0,
#                                             'shortMarginValue': 0.0,
#                                             'shortMarketValue': 0.0,
#                                             'shortOptionMarketValue': 0.0,
#                                             'sma': 2175.74},
#                         'initialBalances': {'accountValue': 2954.9,
#                                             'accruedInterest': 0.0,
#                                             'availableFundsNonMarginableTrade': 2175.74,
#                                             'bondValue': 0.0,
#                                             'buyingPower': 4351.48,
#                                             'cashAvailableForTrading': 0.0,
#                                             'cashBalance': 1250.21,
#                                             'cashReceipts': 0.0,
#                                             'dayTradingBuyingPower': 0.0,
#                                             'dayTradingBuyingPowerCall': 0.0,
#                                             'dayTradingEquityCall': 0.0,
#                                             'equity': 2954.9,
#                                             'equityPercentage': 100.0,
#                                             'isInCall': False,
#                                             'liquidationValue': 2954.9,
#                                             'longMarginValue': 1704.69,
#                                             'longOptionMarketValue': 0.0,
#                                             'longStockValue': 1704.69,
#                                             'maintenanceCall': 0.0,
#                                             'maintenanceRequirement': 512.94,
#                                             'margin': 1250.21,
#                                             'marginBalance': 0.0,
#                                             'marginEquity': 2954.9,
#                                             'moneyMarketFund': 0.0,
#                                             'mutualFundValue': 0.0,
#                                             'pendingDeposits': 0.0,
#                                             'regTCall': 0.0,
#                                             'shortBalance': 0.0,
#                                             'shortMarginValue': 0.0,
#                                             'shortOptionMarketValue': 0.0,
#                                             'shortStockValue': 0.0,
#                                             'totalCash': 0.0},
#                         'isClosingOnlyRestricted': False,
#                         'isDayTrader': False,
#                         'positions': [{'averagePrice': 369.71,
#                                        'currentDayCost': 0.0,
#                                        'currentDayProfitLoss': 18.25,
#                                        'currentDayProfitLossPercentage': 1.07,
#                                        'instrument': {'assetType': 'EQUITY',
#                                                       'cusip': '532457108',
#                                                       'symbol': 'LLY'},
#                                        'longQuantity': 5.0,
#                                        'maintenanceRequirement': 516.23,
#                                        'marketValue': 1720.75,
#                                        'previousSessionLongQuantity': 5.0,
#                                        'settledLongQuantity': 5.0,
#                                        'settledShortQuantity': 0.0,
#                                        'shortQuantity': 0.0},
#                                       {'averagePrice': 2.29,
#                                        'currentDayCost': 0.0,
#                                        'currentDayProfitLoss': 0.01,
#                                        'currentDayProfitLossPercentage': 0.46,
#                                        'instrument': {'assetType': 'EQUITY',
#                                                       'cusip': '00211Y506',
#                                                       'symbol': 'ABIO'},
#                                        'longQuantity': 1.0,
#                                        'maintenanceRequirement': 2.2,
#                                        'marketValue': 2.2,
#                                        'previousSessionLongQuantity': 1.0,
#                                        'settledLongQuantity': 1.0,
#                                        'settledShortQuantity': 0.0,
#                                        'shortQuantity': 0.0}],
#                         'projectedBalances': {'availableFunds': 2175.74,
#                                               'availableFundsNonMarginableTrade': 2175.74,
#                                               'buyingPower': 4351.48,
#                                               'dayTradingBuyingPower': 0.0,
#                                               'dayTradingBuyingPowerCall': 0.0,
#                                               'isInCall': False,
#                                               'maintenanceCall': 0.0,
#                                               'regTCall': 0.0,
#                                               'stockBuyingPower': 4351.48},
#                         'roundTrips': 0,
#                         'type': 'MARGIN'}}]

# %%
# Grab all the transactions for a specific account.
pprint(
    accounts_service.get_transactions(
        account_id=account_number,
        transaction_type=TransactionTypes.All
    )
)
# Out:
# [{'cashBalanceEffectFlag': True,
#   'description': 'FREE BALANCE INTEREST ADJUSTMENT',
#   'fees': {'additionalFee': 0.0,
#            'cdscFee': 0.0,
#            'commission': 0.0,
#            'optRegFee': 0.0,
#            'otherCharges': 0.0,
#            'rFee': 0.0,
#            'regFee': 0.0,
#            'secFee': 0.0},
#   'netAmount': 0.74,
#   'settlementDate': '2022-12-30',
#   'subAccount': '2',
#   'transactionDate': '2022-12-31T04:36:27+0000',
#   'transactionId': 47309111956,
#   'transactionItem': {'accountId': 253157675, 'cost': 0.0},
#   'transactionSubType': 'CA',
#   'type': 'DIVIDEND_OR_INTEREST'},
#  {'cashBalanceEffectFlag': True,
#   'description': 'BUY TRADE',
#   'fees': {'additionalFee': 0.0,
#            'cdscFee': 0.0,
#            'commission': 0.0,
#            'optRegFee': 0.0,
#            'otherCharges': 0.0,
#            'rFee': 0.0,
#            'regFee': 0.0,
#            'secFee': 0.0},
#   'netAmount': -1848.55,
#   'orderDate': '2022-12-24T23:34:23+0000',
#   'orderId': '10020487227',
#   'settlementDate': '2022-12-29',
#   'subAccount': '2',
#   'transactionDate': '2022-12-27T14:31:08+0000',
#   'transactionId': 47172508833,
#   'transactionItem': {'accountId': 253157675,
#                       'amount': 5.0,
#                       'cost': -1848.55,
#                       'instruction': 'BUY',
#                       'instrument': {'assetType': 'EQUITY',
#                                      'cusip': '532457108',
#                                      'symbol': 'LLY'},
#                       'price': 369.71},
#   'transactionSubType': 'BY',
#   'type': 'TRADE'},
#  {'cashBalanceEffectFlag': True,
#   'description': 'FREE BALANCE INTEREST ADJUSTMENT',
#   'fees': {'additionalFee': 0.0,
#            'cdscFee': 0.0,
#            'commission': 0.0,
#            'optRegFee': 0.0,
#            'otherCharges': 0.0,
#            'rFee': 0.0,
#            'regFee': 0.0,
#            'secFee': 0.0},
#   'netAmount': 0.26,
#   'settlementDate': '2022-11-30',
#   'subAccount': '2',
#   'transactionDate': '2022-12-01T04:06:00+0000',
#   'transactionId': 46622364979,
#   'transactionItem': {'accountId': 253157675, 'cost': 0.0},
#   'transactionSubType': 'CA',
#   'type': 'DIVIDEND_OR_INTEREST'},
#  {'cashBalanceEffectFlag': True,
#   'description': 'CLIENT REQUESTED ELECTRONIC FUNDING RECEIPT (FUNDS NOW)',
#   'fees': {'additionalFee': 0.0,
#            'cdscFee': 0.0,
#            'commission': 0.0,
#            'optRegFee': 0.0,
#            'otherCharges': 0.0,
#            'rFee': 0.0,
#            'regFee': 0.0,
#            'secFee': 0.0},
#   'netAmount': 3000.0,
#   'settlementDate': '2022-11-21',
#   'subAccount': '2',
#   'transactionDate': '2022-11-18T06:45:23+0000',
#   'transactionId': 46445091439,
#   'transactionItem': {'accountId': 253157675, 'cost': 0.0},
#   'transactionSubType': 'FI',
#   'type': 'ELECTRONIC_FUND'},
#  {'cashBalanceEffectFlag': True,
#   'description': 'FREE BALANCE INTEREST ADJUSTMENT',
#   'fees': {'additionalFee': 0.0,
#            'cdscFee': 0.0,
#            'commission': 0.0,
#            'optRegFee': 0.0,
#            'otherCharges': 0.0,
#            'rFee': 0.0,
#            'regFee': 0.0,
#            'secFee': 0.0},
#   'netAmount': 0.02,
#   'settlementDate': '2022-10-31',
#   'subAccount': '2',
#   'transactionDate': '2022-11-01T03:14:13+0000',
#   'transactionId': 46067345680,
#   'transactionItem': {'accountId': 253157675, 'cost': 0.0},
#   'transactionSubType': 'CA',
#   'type': 'DIVIDEND_OR_INTEREST'},
#  {'cashBalanceEffectFlag': True,
#   'description': 'FREE BALANCE INTEREST ADJUSTMENT',
#   'fees': {'additionalFee': 0.0,
#            'cdscFee': 0.0,
#            'commission': 0.0,
#            'optRegFee': 0.0,
#            'otherCharges': 0.0,
#            'rFee': 0.0,
#            'regFee': 0.0,
#            'secFee': 0.0},
#   'netAmount': 0.01,
#   'settlementDate': '2022-09-30',
#   'subAccount': '2',
#   'transactionDate': '2022-10-01T03:25:49+0000',
#   'transactionId': 45479700928,
#   'transactionItem': {'accountId': 253157675, 'cost': 0.0},
#   'transactionSubType': 'CA',
#   'type': 'DIVIDEND_OR_INTEREST'},
#  {'cashBalanceEffectFlag': True,
#   'description': 'FREE BALANCE INTEREST ADJUSTMENT',
#   'fees': {'additionalFee': 0.0,
#            'cdscFee': 0.0,
#            'commission': 0.0,
#            'optRegFee': 0.0,
#            'otherCharges': 0.0,
#            'rFee': 0.0,
#            'regFee': 0.0,
#            'secFee': 0.0},
#   'netAmount': 0.01,
#   'settlementDate': '2022-08-31',
#   'subAccount': '2',
#   'transactionDate': '2022-09-01T03:30:54+0000',
#   'transactionId': 44827226671,
#   'transactionItem': {'accountId': 253157675, 'cost': 0.0},
#   'transactionSubType': 'CA',
#   'type': 'DIVIDEND_OR_INTEREST'},
#  {'cashBalanceEffectFlag': True,
#   'description': 'FREE BALANCE INTEREST ADJUSTMENT',
#   'fees': {'additionalFee': 0.0,
#            'cdscFee': 0.0,
#            'commission': 0.0,
#            'optRegFee': 0.0,
#            'otherCharges': 0.0,
#            'rFee': 0.0,
#            'regFee': 0.0,
#            'secFee': 0.0},
#   'netAmount': 0.01,
#   'settlementDate': '2022-07-29',
#   'subAccount': '2',
#   'transactionDate': '2022-07-30T03:15:33+0000',
#   'transactionId': 44195455361,
#   'transactionItem': {'accountId': 253157675, 'cost': 0.0},
#   'transactionSubType': 'CA',
#   'type': 'DIVIDEND_OR_INTEREST'},
#  {'cashBalanceEffectFlag': True,
#   'description': 'BUY TRADE',
#   'fees': {'additionalFee': 0.0,
#            'cdscFee': 0.0,
#            'commission': 0.0,
#            'optRegFee': 0.0,
#            'otherCharges': 0.0,
#            'rFee': 0.0,
#            'regFee': 0.0,
#            'secFee': 0.0},
#   'netAmount': -2.29,
#   'orderDate': '2022-05-19T02:42:06+0000',
#   'orderId': '8402630416',
#   'settlementDate': '2022-05-23',
#   'subAccount': '2',
#   'transactionDate': '2022-05-19T13:30:03+0000',
#   'transactionId': 42778868549,
#   'transactionItem': {'accountId': 253157675,
#                       'amount': 1.0,
#                       'cost': -2.29,
#                       'instruction': 'BUY',
#                       'instrument': {'assetType': 'EQUITY',
#                                      'cusip': '00211Y506',
#                                      'symbol': 'ABIO'},
#                       'price': 2.29},
#   'transactionSubType': 'BY',
#   'type': 'TRADE'},
#  {'cashBalanceEffectFlag': True,
#   'description': 'INTRA-ACCOUNT TRANSFER',
#   'fees': {'additionalFee': 0.0,
#            'cdscFee': 0.0,
#            'commission': 0.0,
#            'optRegFee': 0.0,
#            'otherCharges': 0.0,
#            'rFee': 0.0,
#            'regFee': 0.0,
#            'secFee': 0.0},
#   'netAmount': -100.0,
#   'settlementDate': '2022-02-28',
#   'subAccount': '1',
#   'transactionDate': '2022-03-01T04:24:35+0000',
#   'transactionId': 41016973435,
#   'transactionItem': {'accountId': 253157675, 'cost': 0.0},
#   'transactionSubType': 'IA',
#   'type': 'JOURNAL'},
#  {'cashBalanceEffectFlag': True,
#   'description': 'INTRA-ACCOUNT TRANSFER',
#   'fees': {'additionalFee': 0.0,
#            'cdscFee': 0.0,
#            'commission': 0.0,
#            'optRegFee': 0.0,
#            'otherCharges': 0.0,
#            'rFee': 0.0,
#            'regFee': 0.0,
#            'secFee': 0.0},
#   'netAmount': 100.0,
#   'settlementDate': '2022-02-28',
#   'subAccount': '2',
#   'transactionDate': '2022-03-01T04:24:35+0000',
#   'transactionId': 41016973436,
#   'transactionItem': {'accountId': 253157675, 'cost': 0.0},
#   'transactionSubType': 'IA',
#   'type': 'JOURNAL'},
#  {'cashBalanceEffectFlag': True,
#   'description': 'ELECTRONIC NEW ACCOUNT FUNDING',
#   'fees': {'additionalFee': 0.0,
#            'cdscFee': 0.0,
#            'commission': 0.0,
#            'optRegFee': 0.0,
#            'otherCharges': 0.0,
#            'rFee': 0.0,
#            'regFee': 0.0,
#            'secFee': 0.0},
#   'netAmount': 100.0,
#   'settlementDate': '2022-02-28',
#   'subAccount': '1',
#   'transactionDate': '2022-02-25T07:13:22+0000',
#   'transactionId': 40954551668,
#   'transactionItem': {'accountId': 253157675, 'cost': 0.0},
#   'transactionSubType': 'NA',
#   'type': 'ELECTRONIC_FUND'}]

# %%
# Grab a specific transaction for a specific account.
pprint(
    accounts_service.get_transaction(
        account_id=account_number,
        transaction_id='27444883992'
    )
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[53], line 3
#       1 # Grab a specific transaction for a specific account.
#       2 pprint(
# ----> 3     accounts_service.get_transaction(
#       4         account_id=account_number,
#       5         transaction_id='27444883992'
#       6     )
#       7 )
#
# File ~/Library/CloudStorage/OneDrive-Personal/Pool/td-ameritrade-api/td/rest/accounts.py:203, in Accounts.get_transaction(self, account_id, transaction_id)
#     170 def get_transaction(self, account_id: str, transaction_id: str) -> dict:
#     171     """Queries a transaction for a specific account.
#     172
#     173     ### Overview
#    (...)
#     200         )
#     201     """
# --> 203     content = self.session.make_request(
#     204         method='get',
#     205         endpoint=f'accounts/{account_id}/transactions/{transaction_id}'
#     206     )
#     208     return content
#
# File ~/Library/CloudStorage/OneDrive-Personal/Pool/td-ameritrade-api/td/session.py:194, in TdAmeritradeSession.make_request(self, method, endpoint, params, data, json_payload)
#     189 # Log the error.
#     190 logging.error(
#     191     msg=json.dumps(obj=error_dict, indent=4)
#     192 )
# --> 194 raise requests.HTTPError()
#
# HTTPError:

# %% [markdown]
# # User info:

# %%
# Initialize the `UserInfo` service.
user_info_service = td_client.user_info()

# Grab the preferences for a specific account.
pprint(
    user_info_service.get_preferences(
        account_id=account_number
    )
)
# Out:
# {'authTokenTimeout': 'FIFTY_FIVE_MINUTES',
#  'defaultAdvancedToolLaunch': 'NONE',
#  'defaultEquityOrderDuration': 'DAY',
#  'defaultEquityOrderLegInstruction': 'NONE',
#  'defaultEquityOrderMarketSession': 'NORMAL',
#  'defaultEquityOrderPriceLinkType': 'NONE',
#  'defaultEquityOrderType': 'LIMIT',
#  'defaultEquityQuantity': 0,
#  'directEquityRouting': False,
#  'directOptionsRouting': False,
#  'equityTaxLotMethod': 'FIFO',
#  'expressTrading': False,
#  'mutualFundTaxLotMethod': 'FIFO',
#  'optionTaxLotMethod': 'FIFO'}

# %%
# Grab the streamer subscription keys.
pprint(
    user_info_service.get_streamer_subscription_keys(
        account_ids=[account_number]
    )
)
# Out:
# {'keys': [{'key': 'b4faa841ff618cc3bbd8c4757203a7f4a3d932548275e91aad271d5e14d28e2fa9fb48daf986e2429d69ed85384efcb09'}]}

# %%
# Grab User Principals.
pprint(
    user_info_service.get_user_principals()
)
# Out:
# {'accessLevel': 'CUS',
#  'accounts': [{'accountCdDomainId': 'A000000094724983',
#                'accountId': '253157675',
#                'acl': 'BPDRDTDWESF7G1G3G5G7GKGLH1H3H5LTM1MAOCPNQSRFSDT5TETFTOTTUAURXBXNXO',
#                'authorizations': {'advancedMargin': True,
#                                   'apex': False,
#                                   'autoPositionEffect': False,
#                                   'levelTwoQuotes': False,
#                                   'marginTrading': True,
#                                   'optionTradingLevel': 'COVERED',
#                                   'scottradeAccount': False,
#                                   'stockTrading': True,
#                                   'streamerAccess': True,
#                                   'streamingNews': False},
#                'company': 'AMER',
#                'displayName': 'mehdishaf',
#                'preferences': {'authTokenTimeout': 'FIFTY_FIVE_MINUTES',
#                                'defaultAdvancedToolLaunch': 'NONE',
#                                'defaultEquityOrderDuration': 'DAY',
#                                'defaultEquityOrderLegInstruction': 'NONE',
#                                'defaultEquityOrderMarketSession': 'NORMAL',
#                                'defaultEquityOrderPriceLinkType': 'NONE',
#                                'defaultEquityOrderType': 'LIMIT',
#                                'defaultEquityQuantity': 0,
#                                'directEquityRouting': False,
#                                'directOptionsRouting': False,
#                                'equityTaxLotMethod': 'FIFO',
#                                'expressTrading': False,
#                                'mutualFundTaxLotMethod': 'FIFO',
#                                'optionTaxLotMethod': 'FIFO'},
#                'segment': 'AMER',
#                'surrogateIds': {'BOZEL': '336bd431ecb3776d0baa8c140f575c12be31435f',
#                                 'BriefingTrader': '3a387194c17c37ec2553e20c8be2d3d3b84550c6',
#                                 'DART': '37cfab8cbbedf4119e55a1569a007e41ed266b2b',
#                                 'EF': '2609a1aff9644f6a48d1ac3f07f960528ec7695d',
#                                 'Flybits': '1e06b6d32887b07357f51d755d538af132eee21c',
#                                 'GK': '7dee87d5cfe6650ea0d30de854f70ebda3da35a1',
#                                 'HAVAS': '66ce1cbf57f1e23b888dd400c29e040b2d10099d',
#                                 'Investools': 'a1327bd59f873920d6ec865699eca6783499d02d',
#                                 'Layer': '5d2e115f849059462d907ead124ef56a0a0dccb9',
#                                 'Localytics': 'cf6cbb1de1997d520c6f518fd04ed924c5db4597',
#                                 'MGP': '45950ffad2c9efb5b36aa3b838864f82e80bfcc3',
#                                 'MIN': 'cd20726657293ae8b017d5346903d56719380347',
#                                 'MSTAR': '4bd1a9cd62a326a4c08edeef7fa5054d5736069b',
#                                 'Market Edge': 'c53bc6fdad71bc8e3eab625f13a3130d1bbf2152',
#                                 'Market Watch': 'f8cb39ce6d13e7ed19c942611a119df0839f1fd2',
#                                 'OpinionLab': '8b6cb9cf2e9583b54e6c146eda76befdbfc06cfb',
#                                 'PWS': '0d6c962c740c18a0ea70ac55367f13def85f5862',
#                                 'SCARR': '0b654cc39e4e226e7cb59824857fcc51009e7058',
#                                 'SP': 'dd94748a1da526ac60eae0f683732a8bb8245b72',
#                                 'STS': 'c6bcfeccee39ad5cb4ae1e587c1f985582a74510',
#                                 'SiteCatalyst': '84011d20d16167f0623218c26fd52bc66fa5041f',
#                                 'VB': 'f5c918750eec7948e4c4e9f6586ac8bcffd108f6',
#                                 'VCE': '8fa3442f0500accdec934ca65fd77e389d1b05fc',
#                                 'WSOD': '86e623bc946066764102ea745168c74635b89cf8',
#                                 'WallStreetStrategies': '54dc85b0de43d6ff176d65bc8e2f1d9c3c856ce0',
#                                 'Zacks': '07944234f2f143b4d8f145de3353e8fea7386092',
#                                 'ePay': '074908ab73622e5f478ad6e21919cb7f'}}],
#  'exchangeAgreements': {'NASDAQ_EXCHANGE_AGREEMENT': 'ACCEPTED',
#                         'NYSE_EXCHANGE_AGREEMENT': 'ACCEPTED',
#                         'OPRA_EXCHANGE_AGREEMENT': 'ACCEPTED'},
#  'lastLoginTime': '2023-02-01T03:03:14+0000',
#  'loginTime': '2023-02-01T03:35:54+0000',
#  'primaryAccountId': '253157675',
#  'professionalStatus': 'NON_PROFESSIONAL',
#  'quotes': {'isAmexDelayed': False,
#             'isCmeDelayed': True,
#             'isForexDelayed': True,
#             'isIceDelayed': True,
#             'isNasdaqDelayed': False,
#             'isNyseDelayed': False,
#             'isOpraDelayed': False},
#  'stalePassword': False,
#  'streamerInfo': {'accessLevel': 'ACCT',
#                   'acl': 'BPDRDTDWESF7G1G3G5G7GKGLH1H3H5LTM1MAOCPNQSRFSDT5TETFTOTTUAURXBXNXOD2D4D6D8E2E4E6E8F2F4F6H7I1',
#                   'appId': 'mehdishaf',
#                   'streamerBinaryUrl': 'streamer-bin.tdameritrade.com',
#                   'streamerSocketUrl': 'streamer-ws.tdameritrade.com',
#                   'token': 'b48b9474ce7a5962b35b1aecc913315aa07a5ab5',
#                   'tokenTimestamp': '2023-02-01T03:53:34+0000',
#                   'userGroup': 'ACCT'},
#  'streamerSubscriptionKeys': {'keys': [{'key': 'b991ea935cf48da36e29620241f0c80bc7ee5175262c9769ebe4cdd4ddc1e45c94bc11d3fb82ab08924d3e9572ea54217'}]},
#  'tokenExpirationTime': '2023-02-01T04:05:54+0000',
#  'userCdDomainId': 'A000000094724984',
#  'userId': 'mehdishaf'}

# %%
# Method 1, Update the User Preferences.
user_info_service.update_user_preferences(
    account_id=account_number,
    preferences={
        'authTokenTimeout': 'EIGHT_HOURS',
        'defaultAdvancedToolLaunch': 'NONE',
        'defaultEquityOrderDuration': 'DAY',
        'defaultEquityOrderLegInstruction': 'NONE',
        'defaultEquityOrderMarketSession': 'NORMAL',
        'defaultEquityOrderPriceLinkType': 'NONE',
        'defaultEquityOrderType': 'LIMIT',
        'defaultEquityQuantity': 0,
        'equityTaxLotMethod': 'FIFO',
        'expressTrading': True,
        'mutualFundTaxLotMethod': 'FIFO',
        'optionTaxLotMethod': 'FIFO'
    }
)

# %% [markdown]
# # Using watchlists

# %%
# Initialize the `Watchlists` service.
watchlists_service = td_client.watchlists()

# %%
# Grab all watchlists for all accounts.
pprint(
    watchlists_service.get_all_accounts_watchlists()
)
# Out:
# Access Token Expired, refreshing access token...
# [{'accountId': '253157675',
#   'name': 'Indexes',
#   'watchlistId': '1882557907',
#   'watchlistItems': [{'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'INDEX', 'symbol': '$DJI'},
#                       'quantity': 0.0,
#                       'sequenceId': 1},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'SPX'},
#                       'quantity': 0.0,
#                       'sequenceId': 2},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY',
#                                      'symbol': 'COMP:GIDS'},
#                       'quantity': 0.0,
#                       'sequenceId': 3},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'VIX'},
#                       'quantity': 0.0,
#                       'sequenceId': 4}]},
#  {'accountId': '253157675',
#   'name': 'Quotes',
#   'watchlistId': '1882557909',
#   'watchlistItems': [{'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'IBM'},
#                       'quantity': 0.0,
#                       'sequenceId': 1},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'MSFT'},
#                       'quantity': 0.0,
#                       'sequenceId': 2},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'EBAY'},
#                       'quantity': 0.0,
#                       'sequenceId': 3}]},
#  {'accountId': '253157675',
#   'name': 'default',
#   'watchlistId': '1882557903',
#   'watchlistItems': [{'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'SPY'},
#                       'quantity': 0.0,
#                       'sequenceId': 1},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'AAPL'},
#                       'quantity': 0.0,
#                       'sequenceId': 2},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'SPX'},
#                       'quantity': 0.0,
#                       'sequenceId': 3},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'FB'},
#                       'quantity': 0.0,
#                       'sequenceId': 4},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'QQQ'},
#                       'quantity': 0.0,
#                       'sequenceId': 5},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'IWM'},
#                       'quantity': 0.0,
#                       'sequenceId': 6},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'TSLA'},
#                       'quantity': 0.0,
#                       'sequenceId': 7},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'RUT'},
#                       'quantity': 0.0,
#                       'sequenceId': 8},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'BAC'},
#                       'quantity': 0.0,
#                       'sequenceId': 9},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'VXX'},
#                       'quantity': 0.0,
#                       'sequenceId': 10},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'USO'},
#                       'quantity': 0.0,
#                       'sequenceId': 11},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'GOOG'},
#                       'quantity': 0.0,
#                       'sequenceId': 12},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'GLD'},
#                       'quantity': 0.0,
#                       'sequenceId': 13},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'NFLX'},
#                       'quantity': 0.0,
#                       'sequenceId': 14},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'PCLN'},
#                       'quantity': 0.0,
#                       'sequenceId': 15},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'FSLR'},
#                       'quantity': 0.0,
#                       'sequenceId': 16},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'GDX'},
#                       'quantity': 0.0,
#                       'sequenceId': 17},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'MSFT'},
#                       'quantity': 0.0,
#                       'sequenceId': 18},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'SLV'},
#                       'quantity': 0.0,
#                       'sequenceId': 19}]}]

# %%
# Grab a specific watchlist for a specific account.
pprint(
    watchlists_service.get_watchlist(
        account_id=account_number,
        watchlist_id='1882557907'
    )
)
# Out:
# {'accountId': '253157675',
#  'name': 'Indexes',
#  'watchlistId': '1882557907',
#  'watchlistItems': [{'averagePrice': 0.0,
#                      'commission': 0.0,
#                      'instrument': {'assetType': 'INDEX', 'symbol': '$DJI'},
#                      'quantity': 0.0,
#                      'sequenceId': 1},
#                     {'averagePrice': 0.0,
#                      'commission': 0.0,
#                      'instrument': {'assetType': 'EQUITY', 'symbol': 'SPX'},
#                      'quantity': 0.0,
#                      'sequenceId': 2},
#                     {'averagePrice': 0.0,
#                      'commission': 0.0,
#                      'instrument': {'assetType': 'EQUITY',
#                                     'symbol': 'COMP:GIDS'},
#                      'quantity': 0.0,
#                      'sequenceId': 3},
#                     {'averagePrice': 0.0,
#                      'commission': 0.0,
#                      'instrument': {'assetType': 'EQUITY', 'symbol': 'VIX'},
#                      'quantity': 0.0,
#                      'sequenceId': 4}]}

# %%
# Grab all the watchlists for a specific account
pprint(
    watchlists_service.get_accounts_watchlist(
        account_id=account_number
    )
)
# Out:
# [{'accountId': '253157675',
#   'name': 'space companies',
#   'watchlistId': '2126167472',
#   'watchlistItems': [{'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'SPCE'},
#                       'quantity': 0.0,
#                       'sequenceId': 1},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'UFO'},
#                       'quantity': 0.0,
#                       'sequenceId': 2}]},
#  {'accountId': '253157675',
#   'name': 'Quotes',
#   'watchlistId': '1882557909',
#   'watchlistItems': [{'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'IBM'},
#                       'quantity': 0.0,
#                       'sequenceId': 1},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'MSFT'},
#                       'quantity': 0.0,
#                       'sequenceId': 2},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'EBAY'},
#                       'quantity': 0.0,
#                       'sequenceId': 3}]},
#  {'accountId': '253157675',
#   'name': 'default',
#   'watchlistId': '1882557903',
#   'watchlistItems': [{'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'SPY'},
#                       'quantity': 0.0,
#                       'sequenceId': 1},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'AAPL'},
#                       'quantity': 0.0,
#                       'sequenceId': 2},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'SPX'},
#                       'quantity': 0.0,
#                       'sequenceId': 3},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'FB'},
#                       'quantity': 0.0,
#                       'sequenceId': 4},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'QQQ'},
#                       'quantity': 0.0,
#                       'sequenceId': 5},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'IWM'},
#                       'quantity': 0.0,
#                       'sequenceId': 6},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'TSLA'},
#                       'quantity': 0.0,
#                       'sequenceId': 7},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'RUT'},
#                       'quantity': 0.0,
#                       'sequenceId': 8},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'BAC'},
#                       'quantity': 0.0,
#                       'sequenceId': 9},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'VXX'},
#                       'quantity': 0.0,
#                       'sequenceId': 10},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'USO'},
#                       'quantity': 0.0,
#                       'sequenceId': 11},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'GOOG'},
#                       'quantity': 0.0,
#                       'sequenceId': 12},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'GLD'},
#                       'quantity': 0.0,
#                       'sequenceId': 13},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'NFLX'},
#                       'quantity': 0.0,
#                       'sequenceId': 14},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'PCLN'},
#                       'quantity': 0.0,
#                       'sequenceId': 15},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'FSLR'},
#                       'quantity': 0.0,
#                       'sequenceId': 16},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'GDX'},
#                       'quantity': 0.0,
#                       'sequenceId': 17},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'MSFT'},
#                       'quantity': 0.0,
#                       'sequenceId': 18},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'SLV'},
#                       'quantity': 0.0,
#                       'sequenceId': 19}]},
#  {'accountId': '253157675',
#   'name': 'Indexes',
#   'watchlistId': '1882557907',
#   'watchlistItems': [{'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'INDEX', 'symbol': '$DJI'},
#                       'quantity': 0.0,
#                       'sequenceId': 1},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'SPX'},
#                       'quantity': 0.0,
#                       'sequenceId': 2},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY',
#                                      'symbol': 'COMP:GIDS'},
#                       'quantity': 0.0,
#                       'sequenceId': 3},
#                      {'averagePrice': 0.0,
#                       'commission': 0.0,
#                       'instrument': {'assetType': 'EQUITY', 'symbol': 'VIX'},
#                       'quantity': 0.0,
#                       'sequenceId': 4}]}]

# %%
# Define some items for our watchlist.
watchlist_items = [
    {
        'quantity': 0.0,
        'averagePrice': 0.0,
        'commission': 0.0,
        'instrument': {
            'symbol': 'SPCE',
            'assetType': 'EQUITY'
        }
    },
    {
        'quantity': 0.0,
        'averagePrice': 0.0,
        'commission': 0.0,
        'instrument': {
            'symbol': 'UFO',
            'assetType': 'EQUITY'
        }
    }
]

# %%
watchlist_items
# Out:
# [{'quantity': 0.0,
#   'averagePrice': 0.0,
#   'commission': 0.0,
#   'instrument': {'symbol': 'SPCE', 'assetType': 'EQUITY'}},
#  {'quantity': 0.0,
#   'averagePrice': 0.0,
#   'commission': 0.0,
#   'instrument': {'symbol': 'UFO', 'assetType': 'EQUITY'}}]

# %%
# Create a new watchlist.
pprint(
    watchlists_service.create_watchlist(
        account_id=account_number,
        name='space companies',
        watchlist_items=watchlist_items
    )
)
# Out:
# None

# %%
# Update a watchlist.
pprint(
    watchlists_service.update_watchlist(
        account_id=account_number,
        watchlist_id='253157675',
        name='Space_Companies_Current',
        watchlist_items=[
            {
                'quantity': 0.0,
                'averagePrice': 0.0,
                'commission': 0.0,
                'instrument': {
                    'symbol': 'TSLA',
                    'assetType': 'EQUITY'
                },
                'sequenceId': 3
            }
        ]
    )
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[73], line 3
#       1 # Update a watchlist.
#       2 pprint(
# ----> 3     watchlists_service.update_watchlist(
#       4         account_id=account_number,
#       5         watchlist_id='253157675',
#       6         name='Space_Companies_Current',
#       7         watchlist_items=[
#       8             {
#       9                 'quantity': 0.0,
#      10                 'averagePrice': 0.0,
#      11                 'commission': 0.0,
#      12                 'instrument': {
#      13                     'symbol': 'TSLA',
#      14                     'assetType': 'EQUITY'
#      15                 },
#      16                 'sequenceId': 3
#      17             }
#      18         ]
#      19     )
#      20 )
#
# File ~/Library/CloudStorage/OneDrive-Personal/Pool/td-ameritrade-api/td/rest/watchlists.py:218, in Watchlists.update_watchlist(self, account_id, watchlist_id, name, watchlist_items)
#     212 # define the payload
#     213 payload = {
#     214     "name": name,
#     215     "watchlistItems": watchlist_items
#     216 }
# --> 218 content = self.session.make_request(
#     219     method='patch',
#     220     endpoint=f'accounts/{account_id}/watchlists/{watchlist_id}',
#     221     json_payload=payload
#     222 )
#     224 return content
#
# File ~/Library/CloudStorage/OneDrive-Personal/Pool/td-ameritrade-api/td/session.py:194, in TdAmeritradeSession.make_request(self, method, endpoint, params, data, json_payload)
#     189 # Log the error.
#     190 logging.error(
#     191     msg=json.dumps(obj=error_dict, indent=4)
#     192 )
# --> 194 raise requests.HTTPError()
#
# HTTPError:

# %% [markdown]
# # Use instruments
# Search for specific instruments

# %%
# Initialize the `Instruments` service.
instruments_service = td_client.instruments()

# Search for a symbol.
pprint(
    instruments_service.search_instruments(
        symbol='MSFT',
        projection='symbol-search'
    )
)
# Out:
# {'MSFT': {'assetType': 'EQUITY',
#           'cusip': '594918104',
#           'description': 'Microsoft Corporation - Common Stock',
#           'exchange': 'NASDAQ',
#           'symbol': 'MSFT'}}

# %%
from td.utils.enums import Projections
# Search for companies using description regular expression.
pprint(
    instruments_service.search_instruments(
        symbol='[Quantum Computing]',
        projection=Projections.DescriptionRegex
    )
)
# Out:
# {}

# %% [markdown]
# # Price History

# %%
# Initialize the `PriceHistory` service.
price_history_service = td_client.price_history()

# Grab the Price History, with enums.
price_history = price_history_service.get_price_history(
    symbol='MSFT',
    frequency_type=FrequencyType.Minute,
    frequency=1,
    period_type=PeriodType.Day,
    period=10,
    extended_hours_needed=False
)

# %%
pprint(price_history)
# Out:
# {'candles': [{'close': 234.9,
#               'datetime': 1674138600000,
#               'high': 234.98,
#               'low': 233.78,
#               'open': 233.78,
#               'volume': 455341},
#              {'close': 234.36,
#               'datetime': 1674138660000,
#               'high': 234.98,
#               'low': 234.3279,
#               'open': 234.88,
#               'volume': 94944},
#              {'close': 235.03,
#               'datetime': 1674138720000,
#               'high': 235.52,
#               'low': 234.26,
#               'open': 234.37,
#               'volume': 147931},
#              {'close': 235.13,
#               'datetime': 1674138780000,
#               'high': 235.2199,
#               'low': 234.77,
#               'open': 235.03,
#               'volume': 87306},
#              {'close': 234.73,
#               'datetime': 1674138840000,
#               'high': 235.14,
#               'low': 234.63,
#               'open': 235.11,
#               'volume': 79007},
#              {'close': 234.17,
#               'datetime': 1674138900000,
#               'high': 234.725,
#               'low': 233.815,
#               'open': 234.72,
#               'volume': 120682},
#              {'close': 234.23,
#               'datetime': 1674138960000,
#               'high': 234.54,
#               'low': 234.07,
#               'open': 234.0976,
#               'volume': 67593},
#              {'close': 234.1673,
#               'datetime': 1674139020000,
#               'high': 234.48,
#               'low': 234.04,
#               'open': 234.265,
#               'volume': 47227},
#              {'close': 234.48,
#               'datetime': 1674139080000,
#               'high': 234.55,
#               'low': 234.01,
#               'open': 234.18,
#               'volume': 58826},
#              {'close': 234.6859,
#               'datetime': 1674139140000,
#               'high': 234.7,
#               'low': 234.26,
#               'open': 234.45,
#               'volume': 107362},
#              {'close': 234.81,
#               'datetime': 1674139200000,
#               'high': 235.0841,
#               'low': 234.66,
#               'open': 234.69,
#               'volume': 97632},
#              {'close': 234.31,
#               'datetime': 1674139260000,
#               'high': 234.8,
#               'low': 234.255,
#               'open': 234.8,
#               'volume': 63623},
#              {'close': 233.97,
#               'datetime': 1674139320000,
#               'high': 234.3,
#               'low': 233.9,
#               'open': 234.3,
#               'volume': 103602},
#              {'close': 233.495,
#               'datetime': 1674139380000,
#               'high': 234.08,
#               'low': 233.46,
#               'open': 233.985,
#               'volume': 94971},
#              {'close': 233.17,
#               'datetime': 1674139440000,
#               'high': 233.64,
#               'low': 233.1,
#               'open': 233.47,
#               'volume': 73970},
#              {'close': 232.94,
#               'datetime': 1674139500000,
#               'high': 233.2,
#               'low': 232.78,
#               'open': 233.17,
#               'volume': 115242},
#              {'close': 232.71,
#               'datetime': 1674139560000,
#               'high': 233.28,
#               'low': 232.64,
#               'open': 232.94,
#               'volume': 84094},
#              {'close': 232.55,
#               'datetime': 1674139620000,
#               'high': 232.8,
#               'low': 232.45,
#               'open': 232.73,
#               'volume': 106023},
#              {'close': 232.43,
#               'datetime': 1674139680000,
#               'high': 232.81,
#               'low': 232.37,
#               'open': 232.56,
#               'volume': 60207},
#              {'close': 232.29,
#               'datetime': 1674139740000,
#               'high': 232.44,
#               'low': 232.05,
#               'open': 232.43,
#               'volume': 119554},
#              {'close': 232.48,
#               'datetime': 1674139800000,
#               'high': 232.64,
#               'low': 232.215,
#               'open': 232.295,
#               'volume': 109761},
#              {'close': 232.4822,
#               'datetime': 1674139860000,
#               'high': 232.6,
#               'low': 232.33,
#               'open': 232.46,
#               'volume': 48705},
#              {'close': 232.28,
#               'datetime': 1674139920000,
#               'high': 232.51,
#               'low': 232.12,
#               'open': 232.48,
#               'volume': 63968},
#              {'close': 232.38,
#               'datetime': 1674139980000,
#               'high': 232.53,
#               'low': 231.94,
#               'open': 232.3,
#               'volume': 80798},
#              {'close': 232.155,
#               'datetime': 1674140040000,
#               'high': 232.37,
#               'low': 232.08,
#               'open': 232.37,
#               'volume': 49431},
#              {'close': 232.6677,
#               'datetime': 1674140100000,
#               'high': 232.82,
#               'low': 232.155,
#               'open': 232.155,
#               'volume': 128820},
#              {'close': 232.5515,
#               'datetime': 1674140160000,
#               'high': 232.86,
#               'low': 232.459,
#               'open': 232.695,
#               'volume': 37858},
#              {'close': 232.97,
#               'datetime': 1674140220000,
#               'high': 233.0,
#               'low': 232.49,
#               'open': 232.53,
#               'volume': 36140},
#              {'close': 233.14,
#               'datetime': 1674140280000,
#               'high': 233.36,
#               'low': 232.96,
#               'open': 232.96,
#               'volume': 81853},
#              {'close': 232.8901,
#               'datetime': 1674140340000,
#               'high': 233.18,
#               'low': 232.85,
#               'open': 233.11,
#               'volume': 56492},
#              {'close': 232.73,
#               'datetime': 1674140400000,
#               'high': 232.88,
#               'low': 232.6421,
#               'open': 232.88,
#               'volume': 57174},
#              {'close': 232.82,
#               'datetime': 1674140460000,
#               'high': 232.975,
#               'low': 232.65,
#               'open': 232.75,
#               'volume': 59803},
#              {'close': 233.29,
#               'datetime': 1674140520000,
#               'high': 233.38,
#               'low': 232.72,
#               'open': 232.78,
#               'volume': 57376},
#              {'close': 233.0,
#               'datetime': 1674140580000,
#               'high': 233.29,
#               'low': 232.9,
#               'open': 233.29,
#               'volume': 36951},
#              {'close': 232.99,
#               'datetime': 1674140640000,
#               'high': 233.18,
#               'low': 232.9468,
#               'open': 232.9663,
#               'volume': 56960},
#              {'close': 232.67,
#               'datetime': 1674140700000,
#               'high': 233.03,
#               'low': 232.63,
#               'open': 232.99,
#               'volume': 38977},
#              {'close': 232.93,
#               'datetime': 1674140760000,
#               'high': 233.12,
#               'low': 232.68,
#               'open': 232.695,
#               'volume': 75687},
#              {'close': 232.8,
#               'datetime': 1674140820000,
#               'high': 233.1,
#               'low': 232.76,
#               'open': 232.94,
#               'volume': 39354},
#              {'close': 232.9699,
#               'datetime': 1674140880000,
#               'high': 233.1459,
#               'low': 232.66,
#               'open': 232.76,
#               'volume': 72369},
#              {'close': 232.95,
#               'datetime': 1674140940000,
#               'high': 233.09,
#               'low': 232.89,
#               'open': 232.9402,
#               'volume': 50883},
#              {'close': 232.9662,
#               'datetime': 1674141000000,
#               'high': 233.085,
#               'low': 232.78,
#               'open': 232.96,
#               'volume': 31160},
#              {'close': 232.65,
#               'datetime': 1674141060000,
#               'high': 232.96,
#               'low': 232.54,
#               'open': 232.95,
#               'volume': 72620},
#              {'close': 232.14,
#               'datetime': 1674141120000,
#               'high': 232.65,
#               'low': 232.11,
#               'open': 232.65,
#               'volume': 74451},
#              {'close': 232.64,
#               'datetime': 1674141180000,
#               'high': 232.64,
#               'low': 232.16,
#               'open': 232.17,
#               'volume': 29907},
#              {'close': 232.6,
#               'datetime': 1674141240000,
#               'high': 232.88,
#               'low': 232.6,
#               'open': 232.675,
#               'volume': 27714},
#              {'close': 232.311,
#               'datetime': 1674141300000,
#               'high': 232.615,
#               'low': 232.3,
#               'open': 232.58,
#               'volume': 43312},
#              {'close': 232.3,
#               'datetime': 1674141360000,
#               'high': 232.595,
#               'low': 232.2701,
#               'open': 232.31,
#               'volume': 33477},
#              {'close': 233.1171,
#               'datetime': 1674141420000,
#               'high': 233.22,
#               'low': 232.25,
#               'open': 232.337,
#               'volume': 93090},
#              {'close': 232.9,
#               'datetime': 1674141480000,
#               'high': 233.2636,
#               'low': 232.85,
#               'open': 233.13,
#               'volume': 49316},
#              {'close': 232.74,
#               'datetime': 1674141540000,
#               'high': 232.9,
#               'low': 232.66,
#               'open': 232.885,
#               'volume': 37623},
#              {'close': 232.665,
#               'datetime': 1674141600000,
#               'high': 232.99,
#               'low': 232.64,
#               'open': 232.73,
#               'volume': 35155},
#              {'close': 232.685,
#               'datetime': 1674141660000,
#               'high': 232.79,
#               'low': 232.58,
#               'open': 232.6636,
#               'volume': 38961},
#              {'close': 232.82,
#               'datetime': 1674141720000,
#               'high': 232.9,
#               'low': 232.68,
#               'open': 232.73,
#               'volume': 32726},
#              {'close': 232.98,
#               'datetime': 1674141780000,
#               'high': 232.98,
#               'low': 232.74,
#               'open': 232.81,
#               'volume': 29314},
#              {'close': 232.77,
#               'datetime': 1674141840000,
#               'high': 233.0975,
#               'low': 232.75,
#               'open': 232.99,
#               'volume': 54043},
#              {'close': 232.83,
#               'datetime': 1674141900000,
#               'high': 232.87,
#               'low': 232.72,
#               'open': 232.77,
#               'volume': 29296},
#              {'close': 232.99,
#               'datetime': 1674141960000,
#               'high': 233.1,
#               'low': 232.75,
#               'open': 232.83,
#               'volume': 31673},
#              {'close': 232.81,
#               'datetime': 1674142020000,
#               'high': 233.0199,
#               'low': 232.77,
#               'open': 233.01,
#               'volume': 23426},
#              {'close': 232.7278,
#               'datetime': 1674142080000,
#               'high': 232.82,
#               'low': 232.66,
#               'open': 232.81,
#               'volume': 51621},
#              {'close': 232.9134,
#               'datetime': 1674142140000,
#               'high': 232.93,
#               'low': 232.725,
#               'open': 232.725,
#               'volume': 25836},
#              {'close': 232.74,
#               'datetime': 1674142200000,
#               'high': 232.9,
#               'low': 232.65,
#               'open': 232.9,
#               'volume': 23071},
#              {'close': 232.78,
#               'datetime': 1674142260000,
#               'high': 232.97,
#               'low': 232.69,
#               'open': 232.78,
#               'volume': 31145},
#              {'close': 232.39,
#               'datetime': 1674142320000,
#               'high': 232.8211,
#               'low': 232.38,
#               'open': 232.77,
#               'volume': 71459},
#              {'close': 232.2,
#               'datetime': 1674142380000,
#               'high': 232.5,
#               'low': 232.19,
#               'open': 232.39,
#               'volume': 36954},
#              {'close': 232.06,
#               'datetime': 1674142440000,
#               'high': 232.23,
#               'low': 232.0,
#               'open': 232.21,
#               'volume': 80585},
#              {'close': 232.0222,
#               'datetime': 1674142500000,
#               'high': 232.18,
#               'low': 231.92,
#               'open': 232.08,
#               'volume': 48313},
#              {'close': 231.7454,
#               'datetime': 1674142560000,
#               'high': 232.11,
#               'low': 231.7454,
#               'open': 232.0101,
#               'volume': 65948},
#              {'close': 231.65,
#               'datetime': 1674142620000,
#               'high': 231.81,
#               'low': 231.59,
#               'open': 231.75,
#               'volume': 50882},
#              {'close': 232.12,
#               'datetime': 1674142680000,
#               'high': 232.18,
#               'low': 231.655,
#               'open': 231.655,
#               'volume': 73559},
#              {'close': 232.15,
#               'datetime': 1674142740000,
#               'high': 232.37,
#               'low': 232.0834,
#               'open': 232.11,
#               'volume': 84352},
#              {'close': 232.17,
#               'datetime': 1674142800000,
#               'high': 232.508,
#               'low': 232.11,
#               'open': 232.16,
#               'volume': 42289},
#              {'close': 232.271,
#               'datetime': 1674142860000,
#               'high': 232.43,
#               'low': 232.105,
#               'open': 232.17,
#               'volume': 31652},
#              {'close': 232.55,
#               'datetime': 1674142920000,
#               'high': 232.62,
#               'low': 232.213,
#               'open': 232.265,
#               'volume': 34021},
#              {'close': 232.09,
#               'datetime': 1674142980000,
#               'high': 232.58,
#               'low': 232.0401,
#               'open': 232.54,
#               'volume': 43646},
#              {'close': 232.12,
#               'datetime': 1674143040000,
#               'high': 232.26,
#               'low': 232.0018,
#               'open': 232.07,
#               'volume': 36989},
#              {'close': 232.13,
#               'datetime': 1674143100000,
#               'high': 232.13,
#               'low': 231.9,
#               'open': 232.11,
#               'volume': 69352},
#              {'close': 231.67,
#               'datetime': 1674143160000,
#               'high': 232.13,
#               'low': 231.62,
#               'open': 232.13,
#               'volume': 52379},
#              {'close': 232.035,
#               'datetime': 1674143220000,
#               'high': 232.08,
#               'low': 231.5916,
#               'open': 231.6341,
#               'volume': 38772},
#              {'close': 231.69,
#               'datetime': 1674143280000,
#               'high': 232.11,
#               'low': 231.66,
#               'open': 232.05,
#               'volume': 24312},
#              {'close': 231.8729,
#               'datetime': 1674143340000,
#               'high': 231.9,
#               'low': 231.705,
#               'open': 231.705,
#               'volume': 78120},
#              {'close': 231.8,
#               'datetime': 1674143400000,
#               'high': 232.0,
#               'low': 231.8,
#               'open': 231.88,
#               'volume': 50471},
#              {'close': 231.7,
#               'datetime': 1674143460000,
#               'high': 231.86,
#               'low': 231.66,
#               'open': 231.81,
#               'volume': 35423},
#              {'close': 231.61,
#               'datetime': 1674143520000,
#               'high': 231.86,
#               'low': 231.57,
#               'open': 231.7,
#               'volume': 28388},
#              {'close': 231.7301,
#               'datetime': 1674143580000,
#               'high': 231.74,
#               'low': 231.48,
#               'open': 231.6137,
#               'volume': 57639},
#              {'close': 231.49,
#               'datetime': 1674143640000,
#               'high': 231.8032,
#               'low': 231.48,
#               'open': 231.75,
#               'volume': 34666},
#              {'close': 231.24,
#               'datetime': 1674143700000,
#               'high': 231.48,
#               'low': 231.18,
#               'open': 231.48,
#               'volume': 68989},
#              {'close': 231.09,
#               'datetime': 1674143760000,
#               'high': 231.215,
#               'low': 231.05,
#               'open': 231.195,
#               'volume': 44234},
#              {'close': 230.925,
#               'datetime': 1674143820000,
#               'high': 231.155,
#               'low': 230.92,
#               'open': 231.09,
#               'volume': 58883},
#              {'close': 230.86,
#               'datetime': 1674143880000,
#               'high': 231.1095,
#               'low': 230.83,
#               'open': 230.925,
#               'volume': 48886},
#              {'close': 231.1066,
#               'datetime': 1674143940000,
#               'high': 231.248,
#               'low': 230.8718,
#               'open': 230.8718,
#               'volume': 85308},
#              {'close': 231.31,
#               'datetime': 1674144000000,
#               'high': 231.39,
#               'low': 231.03,
#               'open': 231.1,
#               'volume': 83776},
#              {'close': 231.1014,
#               'datetime': 1674144060000,
#               'high': 231.3,
#               'low': 231.02,
#               'open': 231.3,
#               'volume': 48552},
#              {'close': 231.08,
#               'datetime': 1674144120000,
#               'high': 231.1,
#               'low': 230.86,
#               'open': 231.08,
#               'volume': 45690},
#              {'close': 231.1,
#               'datetime': 1674144180000,
#               'high': 231.38,
#               'low': 231.02,
#               'open': 231.05,
#               'volume': 47421},
#              {'close': 231.18,
#               'datetime': 1674144240000,
#               'high': 231.21,
#               'low': 231.02,
#               'open': 231.07,
#               'volume': 39856},
#              {'close': 231.22,
#               'datetime': 1674144300000,
#               'high': 231.34,
#               'low': 231.18,
#               'open': 231.18,
#               'volume': 23424},
#              {'close': 231.2527,
#               'datetime': 1674144360000,
#               'high': 231.28,
#               'low': 231.12,
#               'open': 231.205,
#               'volume': 25805},
#              {'close': 231.49,
#               'datetime': 1674144420000,
#               'high': 231.6093,
#               'low': 231.25,
#               'open': 231.27,
#               'volume': 154419},
#              {'close': 231.74,
#               'datetime': 1674144480000,
#               'high': 231.75,
#               'low': 231.48,
#               'open': 231.52,
#               'volume': 57765},
#              {'close': 231.68,
#               'datetime': 1674144540000,
#               'high': 231.84,
#               'low': 231.68,
#               'open': 231.73,
#               'volume': 59204},
#              {'close': 231.995,
#               'datetime': 1674144600000,
#               'high': 232.0786,
#               'low': 231.655,
#               'open': 231.7,
#               'volume': 75034},
#              {'close': 231.95,
#               'datetime': 1674144660000,
#               'high': 232.08,
#               'low': 231.91,
#               'open': 232.02,
#               'volume': 66366},
#              {'close': 231.925,
#               'datetime': 1674144720000,
#               'high': 231.9799,
#               'low': 231.82,
#               'open': 231.96,
#               'volume': 44096},
#              {'close': 232.03,
#               'datetime': 1674144780000,
#               'high': 232.06,
#               'low': 231.845,
#               'open': 231.93,
#               'volume': 30734},
#              {'close': 231.87,
#               'datetime': 1674144840000,
#               'high': 232.02,
#               'low': 231.8659,
#               'open': 232.02,
#               'volume': 34687},
#              {'close': 231.77,
#               'datetime': 1674144900000,
#               'high': 231.92,
#               'low': 231.77,
#               'open': 231.86,
#               'volume': 40291},
#              {'close': 231.87,
#               'datetime': 1674144960000,
#               'high': 231.91,
#               'low': 231.705,
#               'open': 231.77,
#               'volume': 35194},
#              {'close': 231.74,
#               'datetime': 1674145020000,
#               'high': 231.93,
#               'low': 231.74,
#               'open': 231.88,
#               'volume': 55789},
#              {'close': 231.64,
#               'datetime': 1674145080000,
#               'high': 231.7899,
#               'low': 231.64,
#               'open': 231.735,
#               'volume': 28966},
#              {'close': 231.68,
#               'datetime': 1674145140000,
#               'high': 231.7513,
#               'low': 231.6369,
#               'open': 231.65,
#               'volume': 21657},
#              {'close': 231.4223,
#               'datetime': 1674145200000,
#               'high': 231.69,
#               'low': 231.41,
#               'open': 231.68,
#               'volume': 30158},
#              {'close': 231.36,
#               'datetime': 1674145260000,
#               'high': 231.5,
#               'low': 231.35,
#               'open': 231.4299,
#               'volume': 31829},
#              {'close': 231.34,
#               'datetime': 1674145320000,
#               'high': 231.42,
#               'low': 231.32,
#               'open': 231.36,
#               'volume': 19593},
#              {'close': 231.23,
#               'datetime': 1674145380000,
#               'high': 231.46,
#               'low': 231.23,
#               'open': 231.38,
#               'volume': 33280},
#              {'close': 231.15,
#               'datetime': 1674145440000,
#               'high': 231.22,
#               'low': 231.0401,
#               'open': 231.21,
#               'volume': 49620},
#              {'close': 231.21,
#               'datetime': 1674145500000,
#               'high': 231.34,
#               'low': 231.155,
#               'open': 231.18,
#               'volume': 28021},
#              {'close': 231.17,
#               'datetime': 1674145560000,
#               'high': 231.21,
#               'low': 231.03,
#               'open': 231.21,
#               'volume': 26572},
#              {'close': 231.2872,
#               'datetime': 1674145620000,
#               'high': 231.33,
#               'low': 231.14,
#               'open': 231.15,
#               'volume': 32200},
#              {'close': 231.073,
#               'datetime': 1674145680000,
#               'high': 231.43,
#               'low': 231.065,
#               'open': 231.3,
#               'volume': 33518},
#              {'close': 231.03,
#               'datetime': 1674145740000,
#               'high': 231.14,
#               'low': 231.005,
#               'open': 231.08,
#               'volume': 26817},
#              {'close': 230.97,
#               'datetime': 1674145800000,
#               'high': 231.09,
#               'low': 230.93,
#               'open': 231.01,
#               'volume': 38504},
#              {'close': 231.04,
#               'datetime': 1674145860000,
#               'high': 231.04,
#               'low': 230.78,
#               'open': 230.97,
#               'volume': 52592},
#              {'close': 231.04,
#               'datetime': 1674145920000,
#               'high': 231.14,
#               'low': 230.89,
#               'open': 231.05,
#               'volume': 30027},
#              {'close': 230.93,
#               'datetime': 1674145980000,
#               'high': 231.1,
#               'low': 230.88,
#               'open': 231.04,
#               'volume': 26757},
#              {'close': 230.76,
#               'datetime': 1674146040000,
#               'high': 230.92,
#               'low': 230.7,
#               'open': 230.92,
#               'volume': 29595},
#              {'close': 230.7694,
#               'datetime': 1674146100000,
#               'high': 230.82,
#               'low': 230.68,
#               'open': 230.77,
#               'volume': 48403},
#              {'close': 231.0,
#               'datetime': 1674146160000,
#               'high': 231.0534,
#               'low': 230.76,
#               'open': 230.76,
#               'volume': 36602},
#              {'close': 230.97,
#               'datetime': 1674146220000,
#               'high': 231.14,
#               'low': 230.96,
#               'open': 231.01,
#               'volume': 39319},
#              {'close': 230.97,
#               'datetime': 1674146280000,
#               'high': 231.03,
#               'low': 230.85,
#               'open': 230.96,
#               'volume': 32020},
#              {'close': 230.9517,
#               'datetime': 1674146340000,
#               'high': 230.98,
#               'low': 230.88,
#               'open': 230.96,
#               'volume': 25540},
#              {'close': 231.04,
#               'datetime': 1674146400000,
#               'high': 231.09,
#               'low': 230.9,
#               'open': 230.96,
#               'volume': 54383},
#              {'close': 231.07,
#               'datetime': 1674146460000,
#               'high': 231.07,
#               'low': 230.94,
#               'open': 231.04,
#               'volume': 16392},
#              {'close': 231.17,
#               'datetime': 1674146520000,
#               'high': 231.2,
#               'low': 231.0,
#               'open': 231.05,
#               'volume': 77248},
#              {'close': 230.98,
#               'datetime': 1674146580000,
#               'high': 231.16,
#               'low': 230.82,
#               'open': 231.15,
#               'volume': 50076},
#              {'close': 230.94,
#               'datetime': 1674146640000,
#               'high': 231.05,
#               'low': 230.925,
#               'open': 230.98,
#               'volume': 27015},
#              {'close': 231.19,
#               'datetime': 1674146700000,
#               'high': 231.25,
#               'low': 230.88,
#               'open': 230.92,
#               'volume': 30635},
#              {'close': 231.18,
#               'datetime': 1674146760000,
#               'high': 231.22,
#               'low': 231.06,
#               'open': 231.15,
#               'volume': 29971},
#              {'close': 231.22,
#               'datetime': 1674146820000,
#               'high': 231.25,
#               'low': 231.15,
#               'open': 231.2,
#               'volume': 26184},
#              {'close': 231.2668,
#               'datetime': 1674146880000,
#               'high': 231.4,
#               'low': 231.22,
#               'open': 231.22,
#               'volume': 33864},
#              {'close': 231.507,
#               'datetime': 1674146940000,
#               'high': 231.519,
#               'low': 231.26,
#               'open': 231.27,
#               'volume': 41364},
#              {'close': 231.47,
#               'datetime': 1674147000000,
#               'high': 231.51,
#               'low': 231.43,
#               'open': 231.5,
#               'volume': 22183},
#              {'close': 231.38,
#               'datetime': 1674147060000,
#               'high': 231.53,
#               'low': 231.35,
#               'open': 231.4746,
#               'volume': 26016},
#              {'close': 231.31,
#               'datetime': 1674147120000,
#               'high': 231.37,
#               'low': 231.25,
#               'open': 231.365,
#               'volume': 21429},
#              {'close': 231.1384,
#               'datetime': 1674147180000,
#               'high': 231.38,
#               'low': 231.13,
#               'open': 231.3193,
#               'volume': 28305},
#              {'close': 231.11,
#               'datetime': 1674147240000,
#               'high': 231.16,
#               'low': 231.03,
#               'open': 231.13,
#               'volume': 19703},
#              {'close': 231.185,
#               'datetime': 1674147300000,
#               'high': 231.28,
#               'low': 231.09,
#               'open': 231.105,
#               'volume': 26817},
#              {'close': 231.07,
#               'datetime': 1674147360000,
#               'high': 231.19,
#               'low': 231.03,
#               'open': 231.1799,
#               'volume': 39077},
#              {'close': 231.09,
#               'datetime': 1674147420000,
#               'high': 231.2375,
#               'low': 231.01,
#               'open': 231.06,
#               'volume': 20845},
#              {'close': 231.08,
#               'datetime': 1674147480000,
#               'high': 231.15,
#               'low': 231.06,
#               'open': 231.09,
#               'volume': 10719},
#              {'close': 231.03,
#               'datetime': 1674147540000,
#               'high': 231.06,
#               'low': 230.9265,
#               'open': 231.06,
#               'volume': 31870},
#              {'close': 231.24,
#               'datetime': 1674147600000,
#               'high': 231.31,
#               'low': 231.01,
#               'open': 231.04,
#               'volume': 60274},
#              {'close': 231.33,
#               'datetime': 1674147660000,
#               'high': 231.53,
#               'low': 231.235,
#               'open': 231.24,
#               'volume': 49330},
#              {'close': 231.41,
#               'datetime': 1674147720000,
#               'high': 231.53,
#               'low': 231.28,
#               'open': 231.34,
#               'volume': 21934},
#              {'close': 231.4331,
#               'datetime': 1674147780000,
#               'high': 231.46,
#               'low': 231.27,
#               'open': 231.39,
#               'volume': 12701},
#              {'close': 231.475,
#               'datetime': 1674147840000,
#               'high': 231.58,
#               'low': 231.39,
#               'open': 231.43,
#               'volume': 14993},
#              {'close': 231.605,
#               'datetime': 1674147900000,
#               'high': 231.66,
#               'low': 231.44,
#               'open': 231.49,
#               'volume': 25591},
#              {'close': 231.58,
#               'datetime': 1674147960000,
#               'high': 231.71,
#               'low': 231.54,
#               'open': 231.61,
#               'volume': 20562},
#              {'close': 231.2339,
#               'datetime': 1674148020000,
#               'high': 231.595,
#               'low': 231.165,
#               'open': 231.585,
#               'volume': 50433},
#              {'close': 231.247,
#               'datetime': 1674148080000,
#               'high': 231.27,
#               'low': 231.17,
#               'open': 231.23,
#               'volume': 12591},
#              {'close': 231.3193,
#               'datetime': 1674148140000,
#               'high': 231.33,
#               'low': 231.19,
#               'open': 231.236,
#               'volume': 10181},
#              {'close': 231.4515,
#               'datetime': 1674148200000,
#               'high': 231.6371,
#               'low': 231.34,
#               'open': 231.34,
#               'volume': 16424},
#              {'close': 231.4,
#               'datetime': 1674148260000,
#               'high': 231.486,
#               'low': 231.38,
#               'open': 231.445,
#               'volume': 19222},
#              {'close': 231.44,
#               'datetime': 1674148320000,
#               'high': 231.49,
#               'low': 231.4,
#               'open': 231.405,
#               'volume': 11751},
#              {'close': 231.47,
#               'datetime': 1674148380000,
#               'high': 231.555,
#               'low': 231.455,
#               'open': 231.46,
#               'volume': 14274},
#              {'close': 231.6222,
#               'datetime': 1674148440000,
#               'high': 231.65,
#               'low': 231.46,
#               'open': 231.46,
#               'volume': 32057},
#              {'close': 231.515,
#               'datetime': 1674148500000,
#               'high': 231.68,
#               'low': 231.475,
#               'open': 231.6482,
#               'volume': 71565},
#              {'close': 231.7347,
#               'datetime': 1674148560000,
#               'high': 231.78,
#               'low': 231.515,
#               'open': 231.515,
#               'volume': 49013},
#              {'close': 231.5353,
#               'datetime': 1674148620000,
#               'high': 231.83,
#               'low': 231.5353,
#               'open': 231.75,
#               'volume': 15688},
#              {'close': 231.455,
#               'datetime': 1674148680000,
#               'high': 231.69,
#               'low': 231.44,
#               'open': 231.55,
#               'volume': 15492},
#              {'close': 231.31,
#               'datetime': 1674148740000,
#               'high': 231.48,
#               'low': 231.26,
#               'open': 231.44,
#               'volume': 17916},
#              {'close': 231.25,
#               'datetime': 1674148800000,
#               'high': 231.36,
#               'low': 231.24,
#               'open': 231.34,
#               'volume': 12316},
#              {'close': 231.26,
#               'datetime': 1674148860000,
#               'high': 231.34,
#               'low': 231.22,
#               'open': 231.25,
#               'volume': 23854},
#              {'close': 231.23,
#               'datetime': 1674148920000,
#               'high': 231.26,
#               'low': 231.1466,
#               'open': 231.26,
#               'volume': 15066},
#              {'close': 231.11,
#               'datetime': 1674148980000,
#               'high': 231.23,
#               'low': 231.0687,
#               'open': 231.23,
#               'volume': 23679},
#              {'close': 231.07,
#               'datetime': 1674149040000,
#               'high': 231.13,
#               'low': 231.03,
#               'open': 231.13,
#               'volume': 10248},
#              {'close': 231.134,
#               'datetime': 1674149100000,
#               'high': 231.1967,
#               'low': 231.05,
#               'open': 231.05,
#               'volume': 22297},
#              {'close': 231.04,
#               'datetime': 1674149160000,
#               'high': 231.15,
#               'low': 230.98,
#               'open': 231.13,
#               'volume': 30523},
#              {'close': 231.07,
#               'datetime': 1674149220000,
#               'high': 231.11,
#               'low': 231.04,
#               'open': 231.06,
#               'volume': 16109},
#              {'close': 231.0,
#               'datetime': 1674149280000,
#               'high': 231.1,
#               'low': 230.98,
#               'open': 231.06,
#               'volume': 32467},
#              {'close': 231.02,
#               'datetime': 1674149340000,
#               'high': 231.04,
#               'low': 230.93,
#               'open': 231.0,
#               'volume': 25935},
#              {'close': 231.0,
#               'datetime': 1674149400000,
#               'high': 231.1396,
#               'low': 230.99,
#               'open': 231.02,
#               'volume': 18240},
#              {'close': 231.16,
#               'datetime': 1674149460000,
#               'high': 231.17,
#               'low': 230.93,
#               'open': 231.0,
#               'volume': 20559},
#              {'close': 231.21,
#               'datetime': 1674149520000,
#               'high': 231.27,
#               'low': 231.11,
#               'open': 231.16,
#               'volume': 15675},
#              {'close': 231.17,
#               'datetime': 1674149580000,
#               'high': 231.2253,
#               'low': 231.1333,
#               'open': 231.2199,
#               'volume': 12497},
#              {'close': 231.16,
#               'datetime': 1674149640000,
#               'high': 231.195,
#               'low': 231.13,
#               'open': 231.1652,
#               'volume': 8470},
#              {'close': 231.14,
#               'datetime': 1674149700000,
#               'high': 231.1705,
#               'low': 231.1,
#               'open': 231.16,
#               'volume': 10793},
#              {'close': 231.3159,
#               'datetime': 1674149760000,
#               'high': 231.36,
#               'low': 231.12,
#               'open': 231.12,
#               'volume': 24711},
#              {'close': 231.263,
#               'datetime': 1674149820000,
#               'high': 231.34,
#               'low': 231.2,
#               'open': 231.31,
#               'volume': 26536},
#              {'close': 231.39,
#               'datetime': 1674149880000,
#               'high': 231.4,
#               'low': 231.242,
#               'open': 231.26,
#               'volume': 17847},
#              {'close': 231.3,
#               'datetime': 1674149940000,
#               'high': 231.38,
#               'low': 231.24,
#               'open': 231.38,
#               'volume': 17544},
#              {'close': 231.345,
#               'datetime': 1674150000000,
#               'high': 231.355,
#               'low': 231.24,
#               'open': 231.29,
#               'volume': 10961},
#              {'close': 231.44,
#               'datetime': 1674150060000,
#               'high': 231.5142,
#               'low': 231.31,
#               'open': 231.33,
#               'volume': 20902},
#              {'close': 231.464,
#               'datetime': 1674150120000,
#               'high': 231.53,
#               'low': 231.39,
#               'open': 231.46,
#               'volume': 28944},
#              {'close': 231.32,
#               'datetime': 1674150180000,
#               'high': 231.47,
#               'low': 231.28,
#               'open': 231.4666,
#               'volume': 23422},
#              {'close': 231.32,
#               'datetime': 1674150240000,
#               'high': 231.355,
#               'low': 231.24,
#               'open': 231.31,
#               'volume': 14054},
#              {'close': 231.35,
#               'datetime': 1674150300000,
#               'high': 231.4,
#               'low': 231.21,
#               'open': 231.29,
#               'volume': 16955},
#              {'close': 231.36,
#               'datetime': 1674150360000,
#               'high': 231.45,
#               'low': 231.3,
#               'open': 231.38,
#               'volume': 16103},
#              {'close': 231.21,
#               'datetime': 1674150420000,
#               'high': 231.38,
#               'low': 231.13,
#               'open': 231.37,
#               'volume': 28668},
#              {'close': 231.27,
#               'datetime': 1674150480000,
#               'high': 231.32,
#               'low': 231.2,
#               'open': 231.23,
#               'volume': 11361},
#              {'close': 231.21,
#               'datetime': 1674150540000,
#               'high': 231.33,
#               'low': 231.16,
#               'open': 231.28,
#               'volume': 13390},
#              {'close': 231.28,
#               'datetime': 1674150600000,
#               'high': 231.33,
#               'low': 231.2111,
#               'open': 231.23,
#               'volume': 13334},
#              {'close': 231.09,
#               'datetime': 1674150660000,
#               'high': 231.29,
#               'low': 231.07,
#               'open': 231.29,
#               'volume': 19027},
#              {'close': 231.24,
#               'datetime': 1674150720000,
#               'high': 231.25,
#               'low': 231.06,
#               'open': 231.092,
#               'volume': 19776},
#              {'close': 231.26,
#               'datetime': 1674150780000,
#               'high': 231.27,
#               'low': 231.15,
#               'open': 231.22,
#               'volume': 9054},
#              {'close': 231.12,
#               'datetime': 1674150840000,
#               'high': 231.25,
#               'low': 231.09,
#               'open': 231.25,
#               'volume': 12691},
#              {'close': 231.18,
#               'datetime': 1674150900000,
#               'high': 231.23,
#               'low': 231.08,
#               'open': 231.09,
#               'volume': 8389},
#              {'close': 231.305,
#               'datetime': 1674150960000,
#               'high': 231.31,
#               'low': 231.19,
#               'open': 231.19,
#               'volume': 13177},
#              {'close': 231.335,
#               'datetime': 1674151020000,
#               'high': 231.398,
#               'low': 231.295,
#               'open': 231.3,
#               'volume': 10204},
#              {'close': 231.4,
#               'datetime': 1674151080000,
#               'high': 231.44,
#               'low': 231.31,
#               'open': 231.32,
#               'volume': 21657},
#              {'close': 231.6214,
#               'datetime': 1674151140000,
#               'high': 231.67,
#               'low': 231.38,
#               'open': 231.39,
#               'volume': 29237},
#              {'close': 231.64,
#               'datetime': 1674151200000,
#               'high': 231.79,
#               'low': 231.59,
#               'open': 231.65,
#               'volume': 25181},
#              {'close': 231.8,
#               'datetime': 1674151260000,
#               'high': 231.82,
#               'low': 231.64,
#               'open': 231.64,
#               'volume': 24680},
#              {'close': 231.86,
#               'datetime': 1674151320000,
#               'high': 231.8616,
#               'low': 231.6801,
#               'open': 231.8,
#               'volume': 71914},
#              {'close': 232.26,
#               'datetime': 1674151380000,
#               'high': 232.28,
#               'low': 231.815,
#               'open': 231.85,
#               'volume': 67649},
#              {'close': 232.2,
#               'datetime': 1674151440000,
#               'high': 232.29,
#               'low': 232.12,
#               'open': 232.26,
#               'volume': 21991},
#              {'close': 231.97,
#               'datetime': 1674151500000,
#               'high': 232.24,
#               'low': 231.9575,
#               'open': 232.18,
#               'volume': 35601},
#              {'close': 231.86,
#               'datetime': 1674151560000,
#               'high': 231.9873,
#               'low': 231.8115,
#               'open': 231.9873,
#               'volume': 24831},
#              {'close': 231.83,
#               'datetime': 1674151620000,
#               'high': 231.8599,
#               'low': 231.76,
#               'open': 231.85,
#               'volume': 26166},
#              {'close': 231.78,
#               'datetime': 1674151680000,
#               'high': 231.88,
#               'low': 231.73,
#               'open': 231.83,
#               'volume': 62692},
#              {'close': 231.8,
#               'datetime': 1674151740000,
#               'high': 231.8,
#               'low': 231.7,
#               'open': 231.765,
#               'volume': 35466},
#              {'close': 231.806,
#               'datetime': 1674151800000,
#               'high': 231.91,
#               'low': 231.8,
#               'open': 231.8,
#               'volume': 20887},
#              {'close': 231.7,
#               'datetime': 1674151860000,
#               'high': 231.8,
#               'low': 231.68,
#               'open': 231.8,
#               'volume': 16977},
#              {'close': 231.8601,
#               'datetime': 1674151920000,
#               'high': 231.87,
#               'low': 231.69,
#               'open': 231.7,
#               'volume': 26945},
#              {'close': 232.0,
#               'datetime': 1674151980000,
#               'high': 232.0,
#               'low': 231.845,
#               'open': 231.89,
#               'volume': 21281},
#              {'close': 232.05,
#               'datetime': 1674152040000,
#               'high': 232.065,
#               'low': 231.96,
#               'open': 232.005,
#               'volume': 36449},
#              {'close': 231.97,
#               'datetime': 1674152100000,
#               'high': 232.06,
#               'low': 231.725,
#               'open': 232.055,
#               'volume': 34626},
#              {'close': 231.87,
#               'datetime': 1674152160000,
#               'high': 231.97,
#               'low': 231.81,
#               'open': 231.9401,
#               'volume': 16369},
#              {'close': 231.915,
#               'datetime': 1674152220000,
#               'high': 231.95,
#               'low': 231.84,
#               'open': 231.91,
#               'volume': 18644},
#              {'close': 232.2401,
#               'datetime': 1674152280000,
#               'high': 232.25,
#               'low': 231.915,
#               'open': 231.92,
#               'volume': 24262},
#              {'close': 232.38,
#               'datetime': 1674152340000,
#               'high': 232.4305,
#               'low': 232.25,
#               'open': 232.28,
#               'volume': 55210},
#              {'close': 232.29,
#               'datetime': 1674152400000,
#               'high': 232.44,
#               'low': 232.21,
#               'open': 232.36,
#               'volume': 28191},
#              {'close': 232.6915,
#               'datetime': 1674152460000,
#               'high': 232.7,
#               'low': 232.28,
#               'open': 232.295,
#               'volume': 28287},
#              {'close': 232.582,
#               'datetime': 1674152520000,
#               'high': 232.8,
#               'low': 232.58,
#               'open': 232.74,
#               'volume': 54888},
#              {'close': 232.52,
#               'datetime': 1674152580000,
#               'high': 232.6,
#               'low': 232.42,
#               'open': 232.57,
#               'volume': 25663},
#              {'close': 232.4501,
#               'datetime': 1674152640000,
#               'high': 232.59,
#               'low': 232.43,
#               'open': 232.53,
#               'volume': 22540},
#              {'close': 232.3,
#               'datetime': 1674152700000,
#               'high': 232.48,
#               'low': 232.29,
#               'open': 232.46,
#               'volume': 29826},
#              {'close': 232.1207,
#               'datetime': 1674152760000,
#               'high': 232.36,
#               'low': 232.08,
#               'open': 232.31,
#               'volume': 27940},
#              {'close': 232.08,
#               'datetime': 1674152820000,
#               'high': 232.1695,
#               'low': 232.06,
#               'open': 232.14,
#               'volume': 17069},
#              {'close': 232.215,
#               'datetime': 1674152880000,
#               'high': 232.215,
#               'low': 232.1,
#               'open': 232.12,
#               'volume': 17463},
#              {'close': 232.29,
#               'datetime': 1674152940000,
#               'high': 232.2991,
#               'low': 232.19,
#               'open': 232.22,
#               'volume': 11073},
#              {'close': 232.555,
#               'datetime': 1674153000000,
#               'high': 232.575,
#               'low': 232.3,
#               'open': 232.3,
#               'volume': 27205},
#              {'close': 232.615,
#               'datetime': 1674153060000,
#               'high': 232.68,
#               'low': 232.49,
#               'open': 232.54,
#               'volume': 44515},
#              {'close': 232.5999,
#               'datetime': 1674153120000,
#               'high': 232.7,
#               'low': 232.58,
#               'open': 232.62,
#               'volume': 20089},
#              {'close': 232.49,
#               'datetime': 1674153180000,
#               'high': 232.615,
#               'low': 232.46,
#               'open': 232.585,
#               'volume': 17322},
#              {'close': 232.6,
#               'datetime': 1674153240000,
#               'high': 232.62,
#               'low': 232.3773,
#               'open': 232.5066,
#               'volume': 13412},
#              {'close': 232.71,
#               'datetime': 1674153300000,
#               'high': 232.73,
#               'low': 232.53,
#               'open': 232.61,
#               'volume': 35595},
#              {'close': 233.0,
#               'datetime': 1674153360000,
#               'high': 233.075,
#               'low': 232.73,
#               'open': 232.73,
#               'volume': 52944},
#              {'close': 233.07,
#               'datetime': 1674153420000,
# ...
#               'open': 246.98,
#               'volume': 107522},
#              {'close': 248.45,
#               'datetime': 1675280280000,
#               'high': 248.7006,
#               'low': 247.76,
#               'open': 247.92,
#               'volume': 132791},
#              {'close': 249.31,
#               'datetime': 1675280340000,
#               'high': 249.63,
#               'low': 248.4399,
#               'open': 248.48,
#               'volume': 130262},
#              {'close': 249.52,
#               'datetime': 1675280400000,
#               'high': 249.8,
#               'low': 249.32,
#               'open': 249.32,
#               'volume': 102485},
#              {'close': 249.7,
#               'datetime': 1675280460000,
#               'high': 250.0,
#               'low': 249.6,
#               'open': 249.6,
#               'volume': 94662},
#              {'close': 249.47,
#               'datetime': 1675280520000,
#               'high': 249.98,
#               'low': 249.05,
#               'open': 249.72,
#               'volume': 73095},
#              {'close': 250.48,
#               'datetime': 1675280580000,
#               'high': 250.97,
#               'low': 249.47,
#               'open': 249.56,
#               'volume': 206061},
#              {'close': 250.92,
#               'datetime': 1675280640000,
#               'high': 250.98,
#               'low': 250.33,
#               'open': 250.48,
#               'volume': 74984},
#              {'close': 251.0,
#               'datetime': 1675280700000,
#               'high': 251.16,
#               'low': 250.65,
#               'open': 250.96,
#               'volume': 81603},
#              {'close': 251.76,
#               'datetime': 1675280760000,
#               'high': 251.91,
#               'low': 250.92,
#               'open': 250.975,
#               'volume': 116238},
#              {'close': 251.8299,
#               'datetime': 1675280820000,
#               'high': 252.21,
#               'low': 251.58,
#               'open': 251.812,
#               'volume': 99398},
#              {'close': 252.47,
#               'datetime': 1675280880000,
#               'high': 252.47,
#               'low': 251.6688,
#               'open': 251.76,
#               'volume': 103184},
#              {'close': 252.295,
#               'datetime': 1675280940000,
#               'high': 252.73,
#               'low': 252.1,
#               'open': 252.47,
#               'volume': 144420},
#              {'close': 252.73,
#               'datetime': 1675281000000,
#               'high': 252.85,
#               'low': 252.24,
#               'open': 252.24,
#               'volume': 113368},
#              {'close': 252.61,
#               'datetime': 1675281060000,
#               'high': 252.85,
#               'low': 252.06,
#               'open': 252.77,
#               'volume': 110251},
#              {'close': 252.965,
#               'datetime': 1675281120000,
#               'high': 253.12,
#               'low': 252.34,
#               'open': 252.585,
#               'volume': 139167},
#              {'close': 252.42,
#               'datetime': 1675281180000,
#               'high': 253.0599,
#               'low': 252.18,
#               'open': 252.94,
#               'volume': 82404},
#              {'close': 252.34,
#               'datetime': 1675281240000,
#               'high': 252.63,
#               'low': 252.1,
#               'open': 252.385,
#               'volume': 77717},
#              {'close': 252.47,
#               'datetime': 1675281300000,
#               'high': 252.68,
#               'low': 251.87,
#               'open': 252.36,
#               'volume': 87943},
#              {'close': 252.4,
#               'datetime': 1675281360000,
#               'high': 252.63,
#               'low': 252.1,
#               'open': 252.5,
#               'volume': 83520},
#              {'close': 252.06,
#               'datetime': 1675281420000,
#               'high': 252.44,
#               'low': 251.83,
#               'open': 252.425,
#               'volume': 91397},
#              {'close': 251.96,
#               'datetime': 1675281480000,
#               'high': 252.43,
#               'low': 251.95,
#               'open': 252.01,
#               'volume': 66760},
#              {'close': 252.21,
#               'datetime': 1675281540000,
#               'high': 252.32,
#               'low': 251.94,
#               'open': 251.94,
#               'volume': 51023},
#              {'close': 252.64,
#               'datetime': 1675281600000,
#               'high': 252.86,
#               'low': 252.2,
#               'open': 252.21,
#               'volume': 112280},
#              {'close': 252.5,
#               'datetime': 1675281660000,
#               'high': 252.65,
#               'low': 252.11,
#               'open': 252.65,
#               'volume': 60634},
#              {'close': 252.78,
#               'datetime': 1675281720000,
#               'high': 252.83,
#               'low': 252.5396,
#               'open': 252.5396,
#               'volume': 71469},
#              {'close': 253.24,
#               'datetime': 1675281780000,
#               'high': 253.27,
#               'low': 252.72,
#               'open': 252.79,
#               'volume': 81295},
#              {'close': 252.96,
#               'datetime': 1675281840000,
#               'high': 253.3,
#               'low': 252.94,
#               'open': 253.24,
#               'volume': 79198},
#              {'close': 253.525,
#               'datetime': 1675281900000,
#               'high': 253.53,
#               'low': 252.92,
#               'open': 252.97,
#               'volume': 75228},
#              {'close': 253.49,
#               'datetime': 1675281960000,
#               'high': 253.6,
#               'low': 253.33,
#               'open': 253.53,
#               'volume': 71789},
#              {'close': 253.73,
#               'datetime': 1675282020000,
#               'high': 253.9,
#               'low': 253.32,
#               'open': 253.49,
#               'volume': 123111},
#              {'close': 253.96,
#               'datetime': 1675282080000,
#               'high': 254.12,
#               'low': 253.48,
#               'open': 253.725,
#               'volume': 94092},
#              {'close': 253.8384,
#               'datetime': 1675282140000,
#               'high': 254.14,
#               'low': 253.77,
#               'open': 253.94,
#               'volume': 78235},
#              {'close': 253.521,
#               'datetime': 1675282200000,
#               'high': 253.92,
#               'low': 253.4,
#               'open': 253.83,
#               'volume': 80560},
#              {'close': 253.505,
#               'datetime': 1675282260000,
#               'high': 253.75,
#               'low': 253.34,
#               'open': 253.526,
#               'volume': 78380},
#              {'close': 252.86,
#               'datetime': 1675282320000,
#               'high': 253.49,
#               'low': 252.85,
#               'open': 253.49,
#               'volume': 78789},
#              {'close': 252.88,
#               'datetime': 1675282380000,
#               'high': 253.2,
#               'low': 252.79,
#               'open': 252.86,
#               'volume': 61166},
#              {'close': 253.15,
#               'datetime': 1675282440000,
#               'high': 253.2,
#               'low': 252.87,
#               'open': 252.91,
#               'volume': 118356},
#              {'close': 252.78,
#               'datetime': 1675282500000,
#               'high': 253.22,
#               'low': 252.57,
#               'open': 253.15,
#               'volume': 113058},
#              {'close': 252.13,
#               'datetime': 1675282560000,
#               'high': 252.77,
#               'low': 252.02,
#               'open': 252.74,
#               'volume': 98936},
#              {'close': 252.61,
#               'datetime': 1675282620000,
#               'high': 252.64,
#               'low': 252.06,
#               'open': 252.147,
#               'volume': 87299},
#              {'close': 252.77,
#               'datetime': 1675282680000,
#               'high': 252.87,
#               'low': 252.52,
#               'open': 252.6,
#               'volume': 79110},
#              {'close': 252.9439,
#               'datetime': 1675282740000,
#               'high': 252.99,
#               'low': 252.66,
#               'open': 252.77,
#               'volume': 48380},
#              {'close': 253.13,
#               'datetime': 1675282800000,
#               'high': 253.13,
#               'low': 252.97,
#               'open': 252.98,
#               'volume': 47523},
#              {'close': 252.83,
#               'datetime': 1675282860000,
#               'high': 253.46,
#               'low': 252.81,
#               'open': 253.13,
#               'volume': 104292},
#              {'close': 252.4398,
#               'datetime': 1675282920000,
#               'high': 252.96,
#               'low': 252.31,
#               'open': 252.827,
#               'volume': 55357},
#              {'close': 252.38,
#               'datetime': 1675282980000,
#               'high': 252.62,
#               'low': 252.355,
#               'open': 252.46,
#               'volume': 42654},
#              {'close': 252.78,
#               'datetime': 1675283040000,
#               'high': 252.82,
#               'low': 252.33,
#               'open': 252.39,
#               'volume': 39362},
#              {'close': 252.66,
#               'datetime': 1675283100000,
#               'high': 252.88,
#               'low': 252.66,
#               'open': 252.81,
#               'volume': 36859},
#              {'close': 252.77,
#               'datetime': 1675283160000,
#               'high': 252.98,
#               'low': 252.65,
#               'open': 252.68,
#               'volume': 46516},
#              {'close': 253.04,
#               'datetime': 1675283220000,
#               'high': 253.08,
#               'low': 252.72,
#               'open': 252.76,
#               'volume': 48964},
#              {'close': 253.02,
#               'datetime': 1675283280000,
#               'high': 253.11,
#               'low': 252.8,
#               'open': 253.045,
#               'volume': 46907},
#              {'close': 253.17,
#               'datetime': 1675283340000,
#               'high': 253.23,
#               'low': 252.93,
#               'open': 253.0,
#               'volume': 47317},
#              {'close': 253.3684,
#               'datetime': 1675283400000,
#               'high': 253.47,
#               'low': 253.16,
#               'open': 253.17,
#               'volume': 121497},
#              {'close': 253.12,
#               'datetime': 1675283460000,
#               'high': 253.35,
#               'low': 253.02,
#               'open': 253.35,
#               'volume': 58325},
#              {'close': 253.245,
#               'datetime': 1675283520000,
#               'high': 253.28,
#               'low': 252.96,
#               'open': 253.14,
#               'volume': 45761},
#              {'close': 253.64,
#               'datetime': 1675283580000,
#               'high': 253.66,
#               'low': 253.21,
#               'open': 253.25,
#               'volume': 131925},
#              {'close': 253.7,
#               'datetime': 1675283640000,
#               'high': 253.79,
#               'low': 253.56,
#               'open': 253.65,
#               'volume': 85996},
#              {'close': 254.29,
#               'datetime': 1675283700000,
#               'high': 254.32,
#               'low': 253.68,
#               'open': 253.69,
#               'volume': 131706},
#              {'close': 254.61,
#               'datetime': 1675283760000,
#               'high': 254.69,
#               'low': 254.21,
#               'open': 254.275,
#               'volume': 116392},
#              {'close': 254.99,
#               'datetime': 1675283820000,
#               'high': 255.1,
#               'low': 254.58,
#               'open': 254.61,
#               'volume': 186650},
#              {'close': 254.705,
#               'datetime': 1675283880000,
#               'high': 255.18,
#               'low': 254.63,
#               'open': 254.97,
#               'volume': 117259},
#              {'close': 254.805,
#               'datetime': 1675283940000,
#               'high': 254.85,
#               'low': 254.44,
#               'open': 254.69,
#               'volume': 115245},
#              {'close': 254.75,
#               'datetime': 1675284000000,
#               'high': 254.89,
#               'low': 254.6201,
#               'open': 254.78,
#               'volume': 68057},
#              {'close': 254.74,
#               'datetime': 1675284060000,
#               'high': 255.14,
#               'low': 254.69,
#               'open': 254.76,
#               'volume': 100239},
#              {'close': 254.88,
#               'datetime': 1675284120000,
#               'high': 254.99,
#               'low': 254.58,
#               'open': 254.76,
#               'volume': 96958},
#              {'close': 254.36,
#               'datetime': 1675284180000,
#               'high': 254.9,
#               'low': 254.25,
#               'open': 254.8899,
#               'volume': 101314},
#              {'close': 254.24,
#               'datetime': 1675284240000,
#               'high': 254.48,
#               'low': 254.13,
#               'open': 254.37,
#               'volume': 95501},
#              {'close': 254.04,
#               'datetime': 1675284300000,
#               'high': 254.34,
#               'low': 254.0246,
#               'open': 254.23,
#               'volume': 137085},
#              {'close': 254.13,
#               'datetime': 1675284360000,
#               'high': 254.27,
#               'low': 253.97,
#               'open': 254.04,
#               'volume': 91089},
#              {'close': 253.9,
#               'datetime': 1675284420000,
#               'high': 254.17,
#               'low': 253.77,
#               'open': 254.11,
#               'volume': 98402},
#              {'close': 253.65,
#               'datetime': 1675284480000,
#               'high': 253.9587,
#               'low': 253.61,
#               'open': 253.9113,
#               'volume': 87849},
#              {'close': 253.645,
#               'datetime': 1675284540000,
#               'high': 253.78,
#               'low': 253.49,
#               'open': 253.65,
#               'volume': 105139},
#              {'close': 252.61,
#               'datetime': 1675284600000,
#               'high': 253.6,
#               'low': 252.5,
#               'open': 253.6,
#               'volume': 192845},
#              {'close': 252.78,
#               'datetime': 1675284660000,
#               'high': 252.99,
#               'low': 252.59,
#               'open': 252.63,
#               'volume': 128887},
#              {'close': 252.2319,
#               'datetime': 1675284720000,
#               'high': 252.86,
#               'low': 252.1,
#               'open': 252.785,
#               'volume': 135175},
#              {'close': 252.48,
#               'datetime': 1675284780000,
#               'high': 252.555,
#               'low': 252.2,
#               'open': 252.22,
#               'volume': 154761},
#              {'close': 252.6,
#               'datetime': 1675284840000,
#               'high': 253.03,
#               'low': 252.29,
#               'open': 252.46,
#               'volume': 168242},
#              {'close': 252.99,
#               'datetime': 1675284900000,
#               'high': 252.99,
#               'low': 252.3,
#               'open': 252.61,
#               'volume': 167516},
#              {'close': 252.7601,
#               'datetime': 1675284960000,
#               'high': 253.02,
#               'low': 252.7,
#               'open': 252.99,
#               'volume': 139487},
#              {'close': 252.93,
#               'datetime': 1675285020000,
#               'high': 253.0,
#               'low': 252.61,
#               'open': 252.78,
#               'volume': 152689},
#              {'close': 252.86,
#               'datetime': 1675285080000,
#               'high': 253.09,
#               'low': 252.77,
#               'open': 252.92,
#               'volume': 235239},
#              {'close': 252.75,
#               'datetime': 1675285140000,
#               'high': 252.9,
#               'low': 252.37,
#               'open': 252.86,
#               'volume': 399961}],
#  'empty': False,
#  'symbol': 'MSFT'}

# %%
# The max look back period for minute data is 31 Days.
end_date = datetime.now()
start_date = datetime.now() - timedelta(days=60)

# Grab the Price History, custom time frame.
price_history = price_history_service.get_price_history(
    symbol='MSFT',
    #frequency_type=FrequencyType.Minute,
    frequency_type= FrequencyType.Weekly,
    period_type= 'year',
    frequency=1,
    start_date=start_date,
    end_date=end_date,
    extended_hours_needed=False
)
print(price_history['candles'])
# Out:
# [{'open': 252.01, 'high': 253.819, 'low': 242.205, 'close': 245.42, 'volume': 109602043, 'datetime': 1670220000000}, {'open': 247.445, 'high': 263.915, 'low': 243.51, 'close': 244.69, 'volume': 229942973, 'datetime': 1670824800000}, {'open': 244.86, 'high': 245.615, 'low': 233.87, 'close': 238.73, 'volume': 128396491, 'datetime': 1671429600000}, {'open': 238.7, 'high': 241.92, 'low': 234.17, 'close': 239.82, 'volume': 75854917, 'datetime': 1672034400000}, {'open': 243.08, 'high': 245.75, 'low': 219.35, 'close': 224.93, 'volume': 159562627, 'datetime': 1672639200000}, {'open': 226.45, 'high': 239.9, 'low': 226.41, 'close': 239.23, 'volume': 131675747, 'datetime': 1673244000000}, {'open': 237.97, 'high': 242.38, 'low': 230.68, 'close': 240.22, 'volume': 123872791, 'datetime': 1673848800000}, {'open': 241.1, 'high': 249.83, 'low': 230.9, 'close': 248.16, 'volume': 198648466, 'datetime': 1674453600000}, {'open': 244.51, 'high': 264.69, 'low': 242.2, 'close': 264.6, 'volume': 123608786, 'datetime': 1675058400000}]
